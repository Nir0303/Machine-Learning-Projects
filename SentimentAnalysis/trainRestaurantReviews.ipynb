# %%
sc

# %%
sqlContext

# %%
from pprint import pprint
import nltk
import nltk.corpus as corpus
import json
from collections import defaultdict
import itertools
import math
import re
from nltk.corpus import wordnet
import pickle
from __future__ import print_function
import pandas as pd
import bokeh

# %% [markdown]
# Input learned DataSet

# %%
ReviewRDD= sc.textFile('hdfs:///reviewsR.txt')

# %%
pprint(ReviewRDD.take(5))
# Out:
# [u'Judging from previous posts this used to be a good place, but not any longer.~negative',
#  u'We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.~negative',
#  u'They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.~negative',
#  u'The food was lousy - too sweet or too salty and the portions tiny.~negative',
#  u'After all that, they complained to me about the small tip.~negative']

# %% [markdown]
# Function to get Synonyms and parse text

# %%
def synonyms(x):
    "generate list of synonyms for given word"
    w=wordnet.synsets(x)
    t=[]
    for i in w:
        s=str(i)
        s= re.sub('Synset\(','',s)[1:-2]
        t.extend(wordnet.synset(s).lemma_names())
    return [ i.lower() for i in t  if not any( j in str(i) for j  in ['.','_','-',',']) ][:6]

def parse(x):
    "parse text to list of words with synonyms"
    #porter = nltk.PorterStemmer()
    x=x.split('~')
    y=re.split(r'[^\w]',x[0])
    #y=[porter.stem(i.lower()) for i in y if len(i) >3 or i=='not']
    y=[re.sub(r'\.|,','',i.lower()) for i in y if len(i)>3 or i=='not']
    words=[]
    for i in y:
        words.extend(synonyms(i))
    return (words,x[1])

pprint(parse(u'Rude service, medicore food...there are tons of restaurants in NY...stay away from this one~negative'))
# Out:
# ([u'rude',
#   u'unmannered',
#   u'unmannerly',
#   u'bounderish',
#   u'lowbred',
#   u'rude',
#   u'service',
#   u'service',
#   u'service',
#   u'service',
#   u'service',
#   u'service',
#   u'food',
#   u'nutrient',
#   u'food',
#   u'food',
#   u'there',
#   u'there',
#   u'there',
#   u'there',
#   u'thither',
#   u'tons',
#   u'dozens',
#   u'heaps',
#   u'lots',
#   u'piles',
#   u'scores',
#   u'restaurant',
#   u'eatery',
#   u'stay',
#   u'arrest',
#   u'check',
#   u'halt',
#   u'hitch',
#   u'stay',
#   u'away',
#   u'away',
#   u'away',
#   u'outside',
#   u'away',
#   u'off'],
#  u'negative')

# %% [markdown]
# Generate RDD of parsed o/p

# %%
ReviewPRDD=ReviewRDD.map(lambda x: parse(x)).map(lambda (x,y):(list(set(x)),y))
ReviewPRDD.cache()
# Out:
# PythonRDD[3] at RDD at PythonRDD.scala:43

# %%
pprint(ReviewPRDD.take(1))
# Out:
# [([u'old',
#    u'not',
#    u'goodness',
#    u'apply',
#    u'previous',
#    u'use',
#    u'utilize',
#    u'long',
#    u'late',
#    u'station',
#    u'judging',
#    u'non',
#    u'good',
#    u'utilise',
#    u'evaluate',
#    u'spot',
#    u'judgement',
#    u'yearner',
#    u'judge',
#    u'post',
#    u'judgment',
#    u'former',
#    u'berth',
#    u'longer',
#    u'commodity',
#    u'thirster',
#    u'employ',
#    u'place',
#    u'position',
#    u'property'],
#   u'negative')]

# %% [markdown]
# Create broadcast variable of all words for feature vector

# %%
all_words=ReviewPRDD.map(lambda (x,y): (x))\
                    .flatMap(lambda x:x).map(lambda x: (x,1))\
                    .reduceByKey(lambda x,y:x+y)\
                    .map(lambda (x,y): (x))

wordsb=sc.broadcast(all_words.collect())

# %%
wordsb

# %% [markdown]
# Function for feature vector generation

# %%
def extract_features(x,wordsb):
    d={}
    for i in wordsb.value:
        d['contains {}'.format(i)]= i in x
    return d

# %% [markdown]
# Feature Vector RDD Creation

# %%
ReviewfRDD=ReviewPRDD.map(lambda (x,y): (extract_features(x,wordsb),y))

# %%
ReviewfRDD.take(2)
# Out:
# [({'contains sizing': False,
#    'contains sickly': False,
#    'contains frost': False,
#    'contains quaint': False,
#    'contains relatively': False,
#    'contains youngster': False,
#    'contains bungling': False,
#    'contains farewell': False,
#    'contains tetrad': False,
#    'contains setback': False,
#    'contains rarified': False,
#    'contains burger': False,
#    'contains alien': False,
#    'contains houseclean': False,
#    'contains dispatch': False,
#    'contains honor': False,
#    'contains glorify': False,
#    'contains curry': False,
#    'contains perspective': False,
#    'contains authority': False,
#    'contains invariable': False,
#    'contains viridity': False,
#    'contains starter': False,
#    'contains equitable': False,
#    'contains distillery': False,
#    'contains pry': False,
#    'contains consistent': False,
#    'contains child': False,
#    'contains junket': False,
#    'contains ego': False,
#    'contains thick': False,
#    'contains hustle': False,
#    'contains okay': False,
#    'contains pro': False,
#    'contains visit': False,
#    'contains semi': False,
#    'contains glad': False,
#    'contains affect': False,
#    'contains desire': False,
#    'contains dissimilar': False,
#    'contains definitely': False,
#    'contains lady': False,
#    'contains sottish': False,
#    "contains 'tween": False,
#    'contains though': False,
#    'contains marinara': False,
#    'contains clientele': False,
#    'contains hanger': False,
#    'contains plastic': False,
#    'contains prima': False,
#    'contains crave': False,
#    'contains prime': False,
#    'contains conjecture': False,
#    'contains reserve': False,
#    'contains favorite': False,
#    'contains attention': False,
#    'contains bustle': False,
#    'contains potable': False,
#    'contains month': False,
#    'contains crisp': False,
#    'contains remove': False,
#    'contains liqueur': False,
#    'contains judgement': True,
#    'contains demur': False,
#    'contains jampack': False,
#    'contains evaluate': True,
#    'contains anti': False,
#    'contains courteous': False,
#    'contains commodity': True,
#    'contains crimson': False,
#    'contains scene': False,
#    'contains manager': False,
#    'contains branching': False,
#    'contains interrupt': False,
#    'contains severely': False,
#    'contains forever': False,
#    'contains discreet': False,
#    'contains unostentatious': False,
#    'contains quetch': False,
#    'contains choice': False,
#    'contains blackguard': False,
#    'contains foresee': False,
#    'contains scare': False,
#    'contains attempt': False,
#    'contains grin': False,
#    'contains river': False,
#    'contains ramp': False,
#    'contains trousering': False,
#    'contains stipulate': False,
#    'contains slop': False,
#    'contains previous': True,
#    'contains patently': False,
#    'contains belike': False,
#    'contains indite': False,
#    'contains bakehouse': False,
#    'contains terminated': False,
#    'contains shove': False,
#    'contains testimonial': False,
#    'contains redress': False,
#    'contains xanthous': False,
#    'contains hideous': False,
#    'contains adumbrate': False,
#    'contains newcomer': False,
#    'contains witness': False,
#    'contains enamor': False,
#    'contains grime': False,
#    'contains hush': False,
#    'contains jabber': False,
#    'contains tunny': False,
#    'contains gap': False,
#    'contains deplorably': False,
#    'contains gelatin': False,
#    'contains chichi': False,
#    'contains befall': False,
#    'contains left': False,
#    'contains sliced': False,
#    'contains outing': False,
#    'contains table': False,
#    'contains back': False,
#    'contains gag': False,
#    'contains dahl': False,
#    'contains digression': False,
#    'contains baluchi': False,
#    'contains node': False,
#    'contains negociate': False,
#    'contains valuate': False,
#    'contains stylishness': False,
#    'contains case': False,
#    'contains muddy': False,
#    'contains drop': False,
#    'contains sitting': False,
#    'contains irritation': False,
#    'contains abdomen': False,
#    'contains forestall': False,
#    'contains grounds': False,
#    'contains early': False,
#    'contains accession': False,
#    'contains reeking': False,
#    'contains closer': False,
#    'contains correct': False,
#    'contains seance': False,
#    'contains come': False,
#    'contains asking': False,
#    'contains chesty': False,
#    'contains search': False,
#    'contains date': False,
#    'contains lacking': False,
#    'contains plenteous': False,
#    'contains afloat': False,
#    'contains life': False,
#    'contains double': False,
#    'contains salesclerk': False,
#    'contains walk': False,
#    'contains deal': False,
#    'contains hr': False,
#    'contains devour': False,
#    'contains hipster': False,
#    'contains flooded': False,
#    'contains supposition': False,
#    'contains soup': False,
#    'contains sour': False,
#    'contains employment': False,
#    'contains proceed': False,
#    'contains penchant': False,
#    'contains intimately': False,
#    'contains carnal': False,
#    'contains brobdingnagian': False,
#    'contains spout': False,
#    'contains pretentious': False,
#    'contains assuredness': False,
#    'contains retell': False,
#    'contains popular': False,
#    'contains kid': False,
#    'contains flawlessness': False,
#    'contains exclude': False,
#    'contains staggeringly': False,
#    'contains quaternion': False,
#    'contains wholly': False,
#    'contains generally': False,
#    'contains lunch': False,
#    'contains ace': False,
#    'contains barkeeper': False,
#    'contains cat': False,
#    'contains nevertheless': False,
#    'contains die': False,
#    'contains humus': False,
#    'contains pony': False,
#    'contains formation': False,
#    'contains bone': False,
#    'contains foretell': False,
#    'contains din': False,
#    'contains act': False,
#    'contains daze': False,
#    'contains sense': False,
#    'contains nowadays': False,
#    'contains ordinarily': False,
#    'contains restrain': False,
#    'contains egg': False,
#    'contains defeated': False,
#    'contains tumble': False,
#    'contains character': False,
#    'contains beingness': False,
#    'contains increase': False,
#    'contains foliage': False,
#    'contains competitor': False,
#    'contains birthday': False,
#    'contains forfend': False,
#    'contains scoop': False,
#    'contains cheeseburger': False,
#    'contains centrist': False,
#    'contains society': False,
#    'contains rhombus': False,
#    'contains kicking': False,
#    'contains unbelievably': False,
#    'contains raise': False,
#    'contains unbelievable': False,
#    'contains panini': False,
#    'contains forsake': False,
#    'contains poser': False,
#    'contains particular': False,
#    'contains familiarity': False,
#    'contains sushi': False,
#    'contains rosemary': False,
#    'contains vomitus': False,
#    'contains eventide': False,
#    'contains fairly': False,
#    'contains execute': False,
#    'contains mightiness': False,
#    'contains balthasar': False,
#    'contains enjoy': False,
#    'contains affectionate': False,
#    'contains oyster': False,
#    'contains reading': False,
#    'contains regulation': False,
#    'contains stuporous': False,
#    'contains decorative': False,
#    'contains thoroughly': False,
#    'contains chilling': False,
#    'contains potential': False,
#    'contains neighbourhood': False,
#    'contains min': False,
#    'contains steal': False,
#    'contains steam': False,
#    'contains pace': False,
#    'contains discover': False,
#    'contains particularly': False,
#    'contains miry': False,
#    'contains hat': False,
#    'contains hoummos': False,
#    'contains perchance': False,
#    'contains dissolve': False,
#    'contains modishness': False,
#    'contains soothing': False,
#    'contains italy': False,
#    'contains liberty': False,
#    'contains hands': False,
#    'contains shutting': False,
#    'contains strange': False,
#    'contains pullulate': False,
#    'contains nothingness': False,
#    'contains spicy': False,
#    'contains pudding': False,
#    'contains roosevelt': False,
#    'contains hit': False,
#    'contains subtle': False,
#    'contains tribe': False,
#    'contains gimmick': False,
#    'contains diamond': False,
#    'contains yearn': False,
#    'contains assort': False,
#    'contains innovative': False,
#    'contains chapeau': False,
#    'contains victor': False,
#    'contains dieting': False,
#    'contains angel': False,
#    'contains marshy': False,
#    'contains generously': False,
#    'contains along': False,
#    'contains mash': False,
#    'contains bathetic': False,
#    'contains thirsty': False,
#    'contains howling': False,
#    'contains overcrowd': False,
#    'contains hint': False,
#    'contains campaign': False,
#    'contains inducing': False,
#    'contains pinko': False,
#    'contains impostor': False,
#    'contains acknowledge': False,
#    'contains fallback': False,
#    'contains entail': False,
#    'contains immaculate': False,
#    'contains forthwith': False,
#    'contains balochi': False,
#    'contains truly': False,
#    'contains existent': False,
#    'contains fete': False,
#    'contains helping': False,
#    'contains rendering': False,
#    'contains wrong': False,
#    'contains cambridge': False,
#    'contains postulate': False,
#    'contains converge': False,
#    'contains complete': False,
#    'contains hitting': False,
#    'contains speedily': False,
#    'contains pursuit': False,
#    'contains dearest': False,
#    'contains exaggerated': False,
#    'contains already': False,
#    'contains very': False,
#    'contains decease': False,
#    'contains carnival': False,
#    'contains give': False,
#    'contains residuum': False,
#    'contains blanket': False,
#    'contains pile': False,
#    'contains overlook': False,
#    'contains night': False,
#    'contains passive': False,
#    'contains bar': False,
#    'contains mussitation': False,
#    'contains jurist': False,
#    'contains maize': False,
#    'contains closing': False,
#    'contains costless': False,
#    'contains ovolo': False,
#    'contains apologize': False,
#    'contains warmly': False,
#    'contains kick': False,
#    'contains bad': False,
#    'contains slenderly': False,
#    'contains modification': False,
#    'contains pluck': False,
#    'contains exhibit': False,
#    'contains ultimately': False,
#    'contains several': False,
#    'contains downtown': False,
#    'contains elsewhere': False,
#    'contains lack': False,
#    'contains broadly': False,
#    'contains hubby': False,
#    'contains toppingly': False,
#    'contains much': False,
#    'contains hone': False,
#    'contains success': False,
#    'contains thai': False,
#    'contains dressing': False,
#    'contains thaw': False,
#    'contains untempting': False,
#    'contains skimpy': False,
#    'contains above': False,
#    'contains overprice': False,
#    'contains mussy': False,
#    'contains there': False,
#    'contains speed': False,
#    'contains solution': False,
#    'contains resemble': False,
#    'contains exotic': False,
#    'contains downy': False,
#    'contains launch': False,
#    'contains fashioning': False,
#    'contains chintzily': False,
#    'contains stoppage': False,
#    'contains fleck': False,
#    'contains alert': False,
#    'contains conditions': False,
#    'contains lavatory': False,
#    'contains creative': False,
#    'contains enliven': False,
#    'contains sentience': False,
#    'contains consolation': False,
#    'contains commons': False,
#    'contains hang': False,
#    'contains vary': False,
#    'contains celebrate': False,
#    'contains hand': False,
#    'contains master': False,
#    'contains arrant': False,
#    'contains standard': False,
#    'contains newly': False,
#    'contains allergy': False,
#    'contains disengagement': False,
#    'contains derisory': False,
#    'contains costly': False,
#    'contains terrine': False,
#    'contains certainly': False,
#    'contains emetic': False,
#    'contains siam': False,
#    'contains self': False,
#    'contains hapless': False,
#    'contains stop': False,
#    'contains comfy': False,
#    'contains heaving': False,
#    'contains sauce': False,
#    'contains put': False,
#    'contains push': False,
#    'contains seeking': False,
#    'contains risotto': False,
#    'contains assortment': False,
#    'contains roller': False,
#    'contains 1000': False,
#    'contains pud': False,
#    'contains view': False,
#    'contains edo': False,
#    'contains bunk': False,
#    'contains diminutive': False,
#    'contains solidness': False,
#    'contains unsmooth': False,
#    'contains bringing': False,
#    'contains glow': False,
#    'contains parenthesis': False,
#    'contains madras': False,
#    'contains vociferation': False,
#    'contains avowedly': False,
#    'contains null': False,
#    'contains mentum': False,
#    'contains outflank': False,
#    'contains poor': False,
#    'contains fairish': False,
#    'contains furnish': False,
#    'contains rapid': False,
#    'contains bleary': False,
#    'contains desk': False,
#    'contains endeavour': False,
#    'contains vacation': False,
#    'contains point': False,
#    'contains possessor': False,
#    'contains lower': False,
#    'contains folks': False,
#    'contains afternoon': False,
#    'contains waltz': False,
#    'contains moreover': False,
#    'contains weird': False,
#    'contains naan': False,
#    'contains sometime': False,
#    'contains drunken': False,
#    'contains venter': False,
#    'contains laughingstock': False,
#    'contains breath': False,
#    'contains band': False,
#    'contains bang': False,
#    'contains tiddly': False,
#    'contains eye': False,
#    'contains sard': False,
#    'contains memory': False,
#    'contains forenoon': False,
#    'contains downstair': False,
#    'contains hunt': False,
#    'contains least': False,
#    'contains story': False,
#    'contains mutter': False,
#    'contains store': False,
#    'contains hudson': False,
#    'contains ill': False,
#    'contains condition': False,
#    'contains storm': False,
#    'contains lease': False,
#    'contains dash': False,
#    'contains cramp': False,
#    'contains creepy': False,
#    'contains scary': False,
#    'contains vinegar': False,
#    'contains smattering': False,
#    'contains composition': False,
#    'contains insert': False,
#    'contains encounter': False,
#    'contains messy': False,
#    'contains grill': False,
#    'contains respect': False,
#    'contains sadly': False,
#    'contains dorsum': False,
#    'contains funfair': False,
#    'contains rosebush': False,
#    'contains suspicious': False,
#    'contains malarky': False,
#    'contains smart': False,
#    'contains squid': False,
#    'contains sofa': False,
#    'contains ballyhoo': False,
#    'contains impression': False,
#    'contains blackfriar': False,
#    'contains improver': False,
#    'contains stooge': False,
#    'contains town': False,
#    'contains vodka': False,
#    'contains drip': False,
#    'contains tramp': False,
#    'contains indoor': False,
#    'contains kiosk': False,
#    'contains violative': False,
#    'contains inhabit': False,
#    'contains ranch': False,
#    'contains vanilla': False,
#    'contains postponement': False,
#    'contains first': False,
#    'contains split': False,
#    'contains work': False,
#    'contains gripe': False,
#    'contains reliable': False,
#    'contains larger': False,
#    'contains steamer': False,
#    'contains parting': False,
#    'contains squash': False,
#    'contains swerve': False,
#    'contains wrap': False,
#    'contains any': False,
#    'contains portion': False,
#    'contains hombre': False,
#    'contains missy': False,
#    'contains dinner': False,
#    'contains intimate': False,
#    'contains hasten': False,
#    'contains small': False,
#    'contains filling': False,
#    'contains hippy': False,
#    'contains truthful': False,
#    'contains advanced': False,
#    'contains confederacy': False,
#    'contains embark': False,
#    'contains utter': False,
#    'contains histrion': False,
#    'contains fishy': False,
#    'contains intercede': False,
#    'contains compel': False,
#    'contains fiber': False,
#    'contains cuisine': False,
#    'contains outdoors': False,
#    'contains os': False,
#    'contains barbecued': False,
#    'contains roll': False,
#    'contains kuki': False,
#    'contains consume': False,
#    'contains someone': False,
#    'contains lawn': False,
#    'contains decompress': False,
#    'contains insure': False,
#    'contains planet': False,
#    'contains writing': False,
#    'contains kill': False,
#    'contains flashy': False,
#    'contains appetizer': False,
#    'contains positioning': False,
#    'contains measure': False,
#    'contains ok': False,
#    'contains trend': False,
#    'contains late': True,
#    'contains floor': False,
#    'contains semitrailer': False,
#    'contains instill': False,
#    'contains satisfy': False,
#    'contains alone': False,
#    'contains methamphetamine': False,
#    'contains return': False,
#    'contains impose': False,
#    'contains cognisant': False,
#    'contains vibrate': False,
#    'contains reuben': False,
#    'contains unisex': False,
#    'contains tryout': False,
#    'contains platter': False,
#    'contains direction': False,
#    'contains accentuate': False,
#    'contains antechamber': False,
#    'contains perceivable': False,
#    'contains monstrously': False,
#    'contains tomorrow': False,
#    'contains overtone': False,
#    'contains instantly': False,
#    'contains lone': False,
#    'contains gladiola': False,
#    'contains minimise': False,
#    'contains superintendent': False,
#    'contains reverse': False,
#    'contains becoming': False,
#    'contains apprehensible': False,
#    'contains attract': False,
#    'contains devotee': False,
#    'contains decide': False,
#    'contains policy': False,
#    'contains purchase': False,
#    'contains need': False,
#    'contains hitch': False,
#    'contains schmooze': False,
#    'contains comrade': False,
#    'contains affordable': False,
#    'contains perplex': False,
#    'contains authentically': False,
#    'contains salmon': False,
#    'contains sudor': False,
#    'contains absurdly': False,
#    'contains retard': False,
#    'contains hiking': False,
#    'contains patio': False,
#    'contains romantic': False,
#    'contains crenature': False,
#    'contains gain': False,
#    'contains coalition': False,
#    'contains bra': False,
#    'contains drumstick': False,
#    'contains health': False,
#    'contains wintertime': False,
#    'contains partake': False,
#    'contains plain': False,
#    'contains surprising': False,
#    'contains apropos': False,
#    'contains occurrence': False,
#    'contains preference': False,
#    'contains reasonable': False,
#    'contains breathless': False,
#    'contains terrible': False,
#    'contains fulfil': False,
#    'contains importantly': False,
#    'contains decorous': False,
#    'contains apparel': False,
#    'contains meth': False,
#    'contains oculus': False,
#    'contains sardius': False,
#    'contains response': False,
#    'contains sleek': False,
#    'contains horridly': False,
#    'contains salutation': False,
#    'contains before': False,
#    'contains autonomy': False,
#    'contains unfold': False,
#    'contains screening': False,
#    'contains helper': False,
#    'contains pizza': False,
#    'contains laughter': False,
#    'contains earnestly': False,
#    'contains align': False,
#    'contains mixologist': False,
#    'contains hastiness': False,
#    'contains coach': False,
#    'contains literate': False,
#    'contains value': False,
#    'contains bankrupt': False,
#    'contains caviare': False,
#    'contains schoolfellow': False,
#    'contains crenation': False,
#    'contains pull': False,
#    'contains motivate': False,
#    'contains veal': False,
#    'contains cargo': False,
#    'contains infrequency': False,
#    'contains jook': False,
#    'contains lilliputian': False,
#    'contains warn': False,
#    'contains eyes': False,
#    'contains volaille': False,
#    'contains hutch': False,
#    'contains mustiness': False,
#    'contains treat': False,
#    'contains recover': False,
#    'contains fixture': False,
#    'contains mitt': False,
#    'contains swain': False,
#    'contains visitor': False,
#    'contains hostess': False,
#    'contains italian': False,
#    'contains significantly': False,
#    'contains session': False,
#    'contains tread': False,
#    'contains gigantic': False,
#    'contains fake': False,
#    'contains mark': False,
#    'contains mare': False,
#    'contains gratuitous': False,
#    'contains remodel': False,
#    'contains adequate': False,
#    'contains specify': False,
#    'contains stagnate': False,
#    'contains refashion': False,
#    'contains daily': False,
#    'contains townspeople': False,
#    'contains schedule': False,
#    'contains addition': False,
#    'contains clip': False,
#    'contains difference': False,
#    'contains commonwealth': False,
#    'contains score': False,
#    'contains serenity': False,
#    'contains order': False,
#    'contains scorn': False,
#    'contains boiler': False,
#    'contains floater': False,
#    'contains special': False,
#    'contains strip': False,
#    'contains arrogate': False,
#    'contains sideboard': False,
#    'contains agency': False,
#    'contains actuate': False,
#    'contains sorrow': False,
#    'contains virgo': False,
#    'contains grow': False,
#    'contains expert': False,
#    'contains ailing': False,
#    'contains learn': False,
#    'contains unequaled': False,
#    'contains stingily': False,
#    'contains establish': False,
#    'contains locating': False,
#    'contains bully': False,
#    'contains rarity': False,
#    'contains cigar': False,
#    'contains watery': False,
#    'contains aspirer': False,
#    'contains warrant': False,
#    'contains hippies': False,
#    'contains groom': False,
#    'contains gratify': False,
#    'contains comic': False,
#    'contains ask': False,
#    'contains snorting': False,
#    'contains inheritance': False,
#    'contains doubtfulness': False,
#    'contains bingle': False,
#    'contains abrupt': False,
#    'contains exist': False,
#    'contains crook': False,
#    'contains sparse': False,
#    'contains audio': False,
#    'contains disappointed': False,
#    'contains cordially': False,
#    'contains invariably': False,
#    'contains acquiring': False,
#    'contains caucasian': False,
#    'contains valse': False,
#    'contains declamatory': False,
#    'contains outcome': False,
#    'contains patronage': False,
#    'contains suffering': False,
#    'contains hype': False,
#    'contains jimmy': False,
#    'contains chips': False,
#    'contains someplace': False,
#    'contains comfortableness': False,
#    'contains customer': False,
#    'contains another': False,
#    'contains joint': False,
#    'contains heedful': False,
#    'contains comportment': False,
#    'contains alternate': False,
#    'contains frightful': False,
#    'contains decor': False,
#    'contains crew': False,
#    'contains manus': False,
#    'contains handed': False,
#    'contains survive': False,
#    'contains attraction': False,
#    'contains picky': False,
#    'contains cook': False,
#    'contains summer': False,
#    'contains power': False,
#    'contains query': False,
#    'contains sinker': False,
#    'contains cool': False,
#    'contains unmanageable': False,
#    'contains convenience': False,
#    'contains pulsation': False,
#    'contains rib': False,
#    'contains responsibility': False,
#    'contains bottleful': False,
#    'contains observation': False,
#    'contains hurriedness': False,
#    'contains melting': False,
#    'contains smiling': False,
#    'contains normal': False,
#    'contains heading': False,
#    'contains elementary': False,
#    'contains towner': False,
#    'contains testament': False,
#    'contains attractor': False,
#    'contains pack': False,
#    'contains piteous': False,
#    'contains inspire': False,
#    'contains shady': False,
#    'contains winner': False,
#    'contains na': False,
#    'contains gnocchi': False,
#    'contains heartily': False,
#    'contains experience': False,
#    'contains nj': False,
#    'contains unconvincing': False,
#    'contains chicness': False,
#    'contains intermediate': False,
#    'contains tasty': False,
#    'contains pertain': False,
#    'contains hideously': False,
#    'contains yeddo': False,
#    'contains boldness': False,
#    'contains jest': False,
#    'contains wannabee': False,
#    'contains malarkey': False,
#    'contains sucker': False,
#    'contains flash': False,
#    'contains stain': False,
#    'contains ground': False,
#    'contains paries': False,
#    'contains township': False,
#    'contains overly': False,
#    'contains taste': False,
#    'contains finis': False,
#    'contains amazing': False,
#    'contains guarantee': False,
#    'contains mouth': False,
#    'contains behave': False,
#    'contains upscale': False,
#    'contains transformation': False,
#    'contains creamy': False,
#    'contains liaise': False,
#    'contains flavor': False,
#    'contains foursquare': False,
#    'contains rhomb': False,
#    'contains nutrient': False,
#    'contains aside': False,
#    'contains saphead': False,
#    'contains ice': False,
#    'contains aesthetic': False,
#    'contains gently': False,
#    'contains noisy': False,
#    'contains substitute': False,
#    'contains clams': False,
#    'contains restate': False,
#    'contains elia': False,
#    'contains randomly': False,
#    'contains animal': False,
#    'contains corona': False,
#    'contains yellowness': False,
#    'contains comparatively': False,
#    'contains style': False,
#    'contains raving': False,
#    'contains stopping': False,
#    'contains clubby': False,
#    'contains readily': False,
#    'contains garden': False,
#    'contains party': False,
#    'contains homelike': False,
#    'contains teenaged': False,
#    'contains gift': False,
#    'contains clothes': False,
#    'contains profits': False,
#    'contains plant': False,
#    'contains duty': False,
#    'contains partly': False,
#    'contains foyer': False,
#    'contains dixieland': False,
#    'contains brainy': False,
#    'contains sashimi': False,
#    'contains endeavor': False,
#    'contains possess': False,
#    'contains open': False,
#    'contains empurple': False,
#    'contains eatable': False,
#    'contains comprise': False,
#    'contains supra': False,
#    'contains postulation': False,
#    'contains enclothe': False,
#    'contains mod': False,
#    'contains eats': False,
#    'contains ostentatious': False,
#    'contains takeaway': False,
#    'contains ticker': False,
#    'contains smash': False,
#    'contains ticket': False,
#    'contains fry': False,
#    'contains remains': False,
#    'contains savouring': False,
#    'contains ahead': False,
#    'contains board': False,
#    'contains admiration': False,
#    'contains jean': False,
#    'contains amoy': False,
#    'contains effects': False,
#    'contains juice': False,
#    'contains square': False,
#    'contains walking': False,
#    'contains hovel': False,
#    'contains duo': False,
#    'contains perfective': False,
#    'contains defy': False,
#    'contains loiter': False,
#    'contains communion': False,
#    'contains high': False,
#    'contains estimate': False,
#    'contains client': False,
#    'contains fold': False,
#    'contains viewing': False,
#    'contains hundred': False,
#    'contains zone': False,
#    'contains folk': False,
#    'contains nearby': False,
#    'contains below': False,
#    'contains vicinity': False,
#    'contains snag': False,
#    'contains pisces': False,
#    'contains perish': False,
#    'contains downstairs': False,
#    'contains indolent': False,
#    'contains morsel': False,
#    'contains destroy': False,
#    'contains watering': False,
#    'contains pink': False,
#    'contains convey': False,
#    'contains meet': False,
#    'contains excuse': False,
#    'contains caprice': False,
#    'contains cabbage': False,
#    'contains patty': False,
#    'contains lonesome': False,
#    'contains casual': False,
#    'contains taiwan': False,
#    'contains gratuity': False,
#    'contains integral': False,
#    'contains indication': False,
#    'contains conserve': False,
#    'contains frankly': False,
#    'contains shaver': False,
#    'contains dissatisfactory': False,
#    'contains things': False,
#    'contains revert': False,
#    'contains tum': False,
#    'contains fashion': False,
#    'contains subtraction': False,
#    'contains topping': False,
#    'contains penny': False,
#    'contains definitive': False,
#    'contains describe': False,
#    'contains puniness': False,
#    'contains bunch': False,
#    'contains eden': False,
#    'contains green': False,
#    'contains unmannerly': False,
#    'contains fashioned': False,
#    'contains calculate': False,
#    'contains likely': False,
#    'contains champion': False,
#    'contains chocolate': False,
#    'contains yellowtail': False,
#    'contains funny': False,
#    'contains jam': False,
#    'contains juncture': False,
#    'contains refuse': False,
#    'contains hut': False,
#    'contains complaint': False,
#    'contains flow': False,
#    'contains hole': False,
#    'contains hold': False,
#    'contains pip': False,
#    'contains enforce': False,
#    'contains carte': False,
#    'contains maine': False,
#    'contains verity': False,
#    'contains bury': False,
#    'contains audience': False,
#    'contains ignition': False,
#    'contains entirely': False,
#    'contains available': False,
#    'contains indorsement': False,
#    'contains telling': False,
#    'contains expect': False,
#    'contains brand': False,
#    'contains heaven': False,
#    'contains vibrant': False,
#    'contains after': False,
#    'contains vegetable': False,
#    'contains scrumptious': False,
#    'contains unbend': False,
#    'contains abode': False,
#    'contains nearly': False,
#    'contains compose': False,
#    'contains dependable': False,
#    'contains flavouring': False,
#    'contains design': False,
#    'contains quibble': False,
#    'contains patron': False,
#    'contains cockeyed': False,
#    'contains whatever': False,
#    'contains marvel': False,
#    'contains flirt': False,
#    'contains esteem': False,
#    'contains waiter': False,
#    'contains wish': False,
#    'contains detest': False,
#    'contains ally': False,
#    'contains barrage': False,
#    'contains introduce': False,
#    'contains divine': False,
#    'contains ciao': False,
#    'contains bounderish': False,
#    'contains debar': False,
#    'contains monish': False,
#    'contains fella': False,
#    'contains endorsement': False,
#    'contains trifle': False,
#    'contains theatre': False,
#    'contains normally': False,
#    'contains concluded': False,
#    'contains doojigger': False,
#    'contains joker': False,
#    ...},
#   u'negative'),
#  ({'contains sizing': False,
#    'contains sickly': False,
#    'contains frost': False,
#    'contains quaint': False,
#    'contains relatively': False,
#    'contains youngster': False,
#    'contains bungling': False,
#    'contains farewell': False,
#    'contains tetrad': True,
#    'contains setback': False,
#    'contains rarified': False,
#    'contains burger': False,
#    'contains alien': False,
#    'contains houseclean': False,
#    'contains dispatch': False,
#    'contains honor': False,
#    'contains glorify': False,
#    'contains curry': False,
#    'contains perspective': False,
#    'contains authority': False,
#    'contains invariable': False,
#    'contains viridity': False,
#    'contains starter': False,
#    'contains equitable': False,
#    'contains distillery': False,
#    'contains pry': False,
#    'contains consistent': False,
#    'contains child': False,
#    'contains junket': False,
#    'contains ego': False,
#    'contains thick': False,
#    'contains hustle': False,
#    'contains okay': False,
#    'contains pro': False,
#    'contains visit': True,
#    'contains semi': False,
#    'contains glad': False,
#    'contains affect': False,
#    'contains desire': False,
#    'contains dissimilar': False,
#    'contains definitely': False,
#    'contains lady': False,
#    'contains sottish': False,
#    "contains 'tween": False,
#    'contains though': False,
#    'contains marinara': False,
#    'contains clientele': False,
#    'contains hanger': False,
#    'contains plastic': False,
#    'contains prima': False,
#    'contains crave': False,
#    'contains prime': False,
#    'contains conjecture': False,
#    'contains reserve': False,
#    'contains favorite': False,
#    'contains attention': False,
#    'contains bustle': False,
#    'contains potable': False,
#    'contains month': False,
#    'contains crisp': False,
#    'contains remove': False,
#    'contains liqueur': False,
#    'contains judgement': False,
#    'contains demur': False,
#    'contains jampack': False,
#    'contains evaluate': False,
#    'contains anti': False,
#    'contains courteous': False,
#    'contains commodity': False,
#    'contains crimson': False,
#    'contains scene': False,
#    'contains manager': False,
#    'contains branching': False,
#    'contains interrupt': False,
#    'contains severely': False,
#    'contains forever': False,
#    'contains discreet': False,
#    'contains unostentatious': False,
#    'contains quetch': False,
#    'contains choice': False,
#    'contains blackguard': False,
#    'contains foresee': False,
#    'contains scare': False,
#    'contains attempt': False,
#    'contains grin': False,
#    'contains river': False,
#    'contains ramp': False,
#    'contains trousering': False,
#    'contains stipulate': False,
#    'contains slop': False,
#    'contains previous': False,
#    'contains patently': False,
#    'contains belike': False,
#    'contains indite': False,
#    'contains bakehouse': False,
#    'contains terminated': False,
#    'contains shove': False,
#    'contains testimonial': False,
#    'contains redress': False,
#    'contains xanthous': False,
#    'contains hideous': False,
#    'contains adumbrate': False,
#    'contains newcomer': False,
#    'contains witness': False,
#    'contains enamor': False,
#    'contains grime': False,
#    'contains hush': False,
#    'contains jabber': False,
#    'contains tunny': False,
#    'contains gap': False,
#    'contains deplorably': False,
#    'contains gelatin': False,
#    'contains chichi': False,
#    'contains befall': False,
#    'contains left': False,
#    'contains sliced': False,
#    'contains outing': False,
#    'contains table': False,
#    'contains back': False,
#    'contains gag': False,
#    'contains dahl': False,
#    'contains digression': False,
#    'contains baluchi': False,
#    'contains node': False,
#    'contains negociate': False,
#    'contains valuate': False,
#    'contains stylishness': False,
#    'contains case': False,
#    'contains muddy': False,
#    'contains drop': False,
#    'contains sitting': False,
#    'contains irritation': False,
#    'contains abdomen': False,
#    'contains forestall': False,
#    'contains grounds': False,
#    'contains early': False,
#    'contains accession': False,
#    'contains reeking': False,
#    'contains closer': False,
#    'contains correct': False,
#    'contains seance': False,
#    'contains come': True,
#    'contains asking': False,
#    'contains chesty': False,
#    'contains search': False,
#    'contains date': False,
#    'contains lacking': False,
#    'contains plenteous': False,
#    'contains afloat': False,
#    'contains life': False,
#    'contains double': False,
#    'contains salesclerk': False,
#    'contains walk': False,
#    'contains deal': False,
#    'contains hr': False,
#    'contains devour': False,
#    'contains hipster': False,
#    'contains flooded': False,
#    'contains supposition': False,
#    'contains soup': False,
#    'contains sour': False,
#    'contains employment': False,
#    'contains proceed': False,
#    'contains penchant': False,
#    'contains intimately': False,
#    'contains carnal': False,
#    'contains brobdingnagian': False,
#    'contains spout': False,
#    'contains pretentious': False,
#    'contains assuredness': False,
#    'contains retell': False,
#    'contains popular': False,
#    'contains kid': False,
#    'contains flawlessness': False,
#    'contains exclude': False,
#    'contains staggeringly': False,
#    'contains quaternion': True,
#    'contains wholly': False,
#    'contains generally': False,
#    'contains lunch': False,
#    'contains ace': False,
#    'contains barkeeper': False,
#    'contains cat': False,
#    'contains nevertheless': False,
#    'contains die': False,
#    'contains humus': False,
#    'contains pony': False,
#    'contains formation': False,
#    'contains bone': False,
#    'contains foretell': False,
#    'contains din': False,
#    'contains act': True,
#    'contains daze': False,
#    'contains sense': False,
#    'contains nowadays': False,
#    'contains ordinarily': False,
#    'contains restrain': False,
#    'contains egg': False,
#    'contains defeated': False,
#    'contains tumble': False,
#    'contains character': False,
#    'contains beingness': False,
#    'contains increase': False,
#    'contains foliage': False,
#    'contains competitor': False,
#    'contains birthday': False,
#    'contains forfend': False,
#    'contains scoop': False,
#    'contains cheeseburger': False,
#    'contains centrist': False,
#    'contains society': False,
#    'contains rhombus': False,
#    'contains kicking': False,
#    'contains unbelievably': False,
#    'contains raise': False,
#    'contains unbelievable': False,
#    'contains panini': False,
#    'contains forsake': False,
#    'contains poser': False,
#    'contains particular': False,
#    'contains familiarity': False,
#    'contains sushi': False,
#    'contains rosemary': False,
#    'contains vomitus': False,
#    'contains eventide': False,
#    'contains fairly': False,
#    'contains execute': False,
#    'contains mightiness': False,
#    'contains balthasar': False,
#    'contains enjoy': False,
#    'contains affectionate': False,
#    'contains oyster': False,
#    'contains reading': False,
#    'contains regulation': False,
#    'contains stuporous': False,
#    'contains decorative': False,
#    'contains thoroughly': False,
#    'contains chilling': False,
#    'contains potential': False,
#    'contains neighbourhood': False,
#    'contains min': False,
#    'contains steal': False,
#    'contains steam': False,
#    'contains pace': False,
#    'contains discover': False,
#    'contains particularly': False,
#    'contains miry': False,
#    'contains hat': False,
#    'contains hoummos': False,
#    'contains perchance': False,
#    'contains dissolve': False,
#    'contains modishness': False,
#    'contains soothing': False,
#    'contains italy': False,
#    'contains liberty': False,
#    'contains hands': False,
#    'contains shutting': False,
#    'contains strange': False,
#    'contains pullulate': False,
#    'contains nothingness': False,
#    'contains spicy': False,
#    'contains pudding': False,
#    'contains roosevelt': False,
#    'contains hit': False,
#    'contains subtle': False,
#    'contains tribe': False,
#    'contains gimmick': False,
#    'contains diamond': False,
#    'contains yearn': False,
#    'contains assort': False,
#    'contains innovative': False,
#    'contains chapeau': False,
#    'contains victor': False,
#    'contains dieting': False,
#    'contains angel': False,
#    'contains marshy': False,
#    'contains generously': False,
#    'contains along': False,
#    'contains mash': False,
#    'contains bathetic': False,
#    'contains thirsty': False,
#    'contains howling': False,
#    'contains overcrowd': False,
#    'contains hint': False,
#    'contains campaign': False,
#    'contains inducing': False,
#    'contains pinko': False,
#    'contains impostor': False,
#    'contains acknowledge': False,
#    'contains fallback': False,
#    'contains entail': False,
#    'contains immaculate': False,
#    'contains forthwith': False,
#    'contains balochi': False,
#    'contains truly': False,
#    'contains existent': False,
#    'contains fete': False,
#    'contains helping': False,
#    'contains rendering': False,
#    'contains wrong': False,
#    'contains cambridge': False,
#    'contains postulate': False,
#    'contains converge': False,
#    'contains complete': False,
#    'contains hitting': False,
#    'contains speedily': False,
#    'contains pursuit': False,
#    'contains dearest': False,
#    'contains exaggerated': False,
#    'contains already': False,
#    'contains very': True,
#    'contains decease': False,
#    'contains carnival': False,
#    'contains give': False,
#    'contains residuum': False,
#    'contains blanket': False,
#    'contains pile': False,
#    'contains overlook': False,
#    'contains night': False,
#    'contains passive': False,
#    'contains bar': False,
#    'contains mussitation': False,
#    'contains jurist': False,
#    'contains maize': False,
#    'contains closing': False,
#    'contains costless': False,
#    'contains ovolo': False,
#    'contains apologize': False,
#    'contains warmly': False,
#    'contains kick': False,
#    'contains bad': False,
#    'contains slenderly': False,
#    'contains modification': False,
#    'contains pluck': False,
#    'contains exhibit': False,
#    'contains ultimately': False,
#    'contains several': False,
#    'contains downtown': False,
#    'contains elsewhere': False,
#    'contains lack': False,
#    'contains broadly': False,
#    'contains hubby': False,
#    'contains toppingly': False,
#    'contains much': False,
#    'contains hone': False,
#    'contains success': False,
#    'contains thai': False,
#    'contains dressing': False,
#    'contains thaw': False,
#    'contains untempting': False,
#    'contains skimpy': False,
#    'contains above': False,
#    'contains overprice': False,
#    'contains mussy': False,
#    'contains there': True,
#    'contains speed': False,
#    'contains solution': False,
#    'contains resemble': False,
#    'contains exotic': False,
#    'contains downy': False,
#    'contains launch': False,
#    'contains fashioning': False,
#    'contains chintzily': False,
#    'contains stoppage': False,
#    'contains fleck': False,
#    'contains alert': False,
#    'contains conditions': False,
#    'contains lavatory': False,
#    'contains creative': False,
#    'contains enliven': False,
#    'contains sentience': False,
#    'contains consolation': False,
#    'contains commons': False,
#    'contains hang': False,
#    'contains vary': False,
#    'contains celebrate': False,
#    'contains hand': False,
#    'contains master': False,
#    'contains arrant': False,
#    'contains standard': False,
#    'contains newly': False,
#    'contains allergy': False,
#    'contains disengagement': False,
#    'contains derisory': False,
#    'contains costly': False,
#    'contains terrine': False,
#    'contains certainly': False,
#    'contains emetic': False,
#    'contains siam': False,
#    'contains self': False,
#    'contains hapless': False,
#    'contains stop': False,
#    'contains comfy': False,
#    'contains heaving': False,
#    'contains sauce': False,
#    'contains put': False,
#    'contains push': False,
#    'contains seeking': False,
#    'contains risotto': False,
#    'contains assortment': False,
#    'contains roller': False,
#    'contains 1000': False,
#    'contains pud': False,
#    'contains view': False,
#    'contains edo': False,
#    'contains bunk': False,
#    'contains diminutive': False,
#    'contains solidness': False,
#    'contains unsmooth': False,
#    'contains bringing': False,
#    'contains glow': False,
#    'contains parenthesis': False,
#    'contains madras': False,
#    'contains vociferation': False,
#    'contains avowedly': False,
#    'contains null': False,
#    'contains mentum': False,
#    'contains outflank': False,
#    'contains poor': False,
#    'contains fairish': False,
#    'contains furnish': False,
#    'contains rapid': False,
#    'contains bleary': False,
#    'contains desk': False,
#    'contains endeavour': False,
#    'contains vacation': False,
#    'contains point': False,
#    'contains possessor': False,
#    'contains lower': False,
#    'contains folks': False,
#    'contains afternoon': False,
#    'contains waltz': False,
#    'contains moreover': False,
#    'contains weird': False,
#    'contains naan': False,
#    'contains sometime': False,
#    'contains drunken': False,
#    'contains venter': False,
#    'contains laughingstock': False,
#    'contains breath': False,
#    'contains band': False,
#    'contains bang': False,
#    'contains tiddly': False,
#    'contains eye': False,
#    'contains sard': False,
#    'contains memory': False,
#    'contains forenoon': False,
#    'contains downstair': False,
#    'contains hunt': False,
#    'contains least': False,
#    'contains story': False,
#    'contains mutter': False,
#    'contains store': False,
#    'contains hudson': False,
#    'contains ill': False,
#    'contains condition': False,
#    'contains storm': False,
#    'contains lease': False,
#    'contains dash': False,
#    'contains cramp': False,
#    'contains creepy': False,
#    'contains scary': False,
#    'contains vinegar': False,
#    'contains smattering': False,
#    'contains composition': False,
#    'contains insert': False,
#    'contains encounter': False,
#    'contains messy': False,
#    'contains grill': False,
#    'contains respect': False,
#    'contains sadly': False,
#    'contains dorsum': False,
#    'contains funfair': False,
#    'contains rosebush': False,
#    'contains suspicious': False,
#    'contains malarky': False,
#    'contains smart': False,
#    'contains squid': False,
#    'contains sofa': False,
#    'contains ballyhoo': False,
#    'contains impression': False,
#    'contains blackfriar': False,
#    'contains improver': False,
#    'contains stooge': False,
#    'contains town': False,
#    'contains vodka': False,
#    'contains drip': False,
#    'contains tramp': False,
#    'contains indoor': False,
#    'contains kiosk': False,
#    'contains violative': False,
#    'contains inhabit': False,
#    'contains ranch': False,
#    'contains vanilla': False,
#    'contains postponement': False,
#    'contains first': False,
#    'contains split': False,
#    'contains work': False,
#    'contains gripe': False,
#    'contains reliable': False,
#    'contains larger': False,
#    'contains steamer': False,
#    'contains parting': False,
#    'contains squash': False,
#    'contains swerve': False,
#    'contains wrap': False,
#    'contains any': False,
#    'contains portion': False,
#    'contains hombre': False,
#    'contains missy': False,
#    'contains dinner': False,
#    'contains intimate': False,
#    'contains hasten': False,
#    'contains small': False,
#    'contains filling': False,
#    'contains hippy': False,
#    'contains truthful': False,
#    'contains advanced': False,
#    'contains confederacy': False,
#    'contains embark': False,
#    'contains utter': False,
#    'contains histrion': False,
#    'contains fishy': False,
#    'contains intercede': False,
#    'contains compel': False,
#    'contains fiber': False,
#    'contains cuisine': False,
#    'contains outdoors': False,
#    'contains os': False,
#    'contains barbecued': False,
#    'contains roll': False,
#    'contains kuki': False,
#    'contains consume': False,
#    'contains someone': False,
#    'contains lawn': False,
#    'contains decompress': False,
#    'contains insure': False,
#    'contains planet': False,
#    'contains writing': False,
#    'contains kill': False,
#    'contains flashy': False,
#    'contains appetizer': False,
#    'contains positioning': False,
#    'contains measure': False,
#    'contains ok': False,
#    'contains trend': False,
#    'contains late': False,
#    'contains floor': False,
#    'contains semitrailer': False,
#    'contains instill': False,
#    'contains satisfy': False,
#    'contains alone': False,
#    'contains methamphetamine': False,
#    'contains return': False,
#    'contains impose': True,
#    'contains cognisant': False,
#    'contains vibrate': False,
#    'contains reuben': False,
#    'contains unisex': False,
#    'contains tryout': False,
#    'contains platter': False,
#    'contains direction': False,
#    'contains accentuate': False,
#    'contains antechamber': False,
#    'contains perceivable': False,
#    'contains monstrously': False,
#    'contains tomorrow': False,
#    'contains overtone': False,
#    'contains instantly': False,
#    'contains lone': False,
#    'contains gladiola': False,
#    'contains minimise': False,
#    'contains superintendent': False,
#    'contains reverse': False,
#    'contains becoming': False,
#    'contains apprehensible': False,
#    'contains attract': False,
#    'contains devotee': False,
#    'contains decide': False,
#    'contains policy': False,
#    'contains purchase': False,
#    'contains need': False,
#    'contains hitch': False,
#    'contains schmooze': False,
#    'contains comrade': False,
#    'contains affordable': False,
#    'contains perplex': False,
#    'contains authentically': False,
#    'contains salmon': False,
#    'contains sudor': False,
#    'contains absurdly': False,
#    'contains retard': False,
#    'contains hiking': False,
#    'contains patio': False,
#    'contains romantic': False,
#    'contains crenature': False,
#    'contains gain': False,
#    'contains coalition': False,
#    'contains bra': False,
#    'contains drumstick': False,
#    'contains health': False,
#    'contains wintertime': False,
#    'contains partake': False,
#    'contains plain': False,
#    'contains surprising': False,
#    'contains apropos': False,
#    'contains occurrence': False,
#    'contains preference': False,
#    'contains reasonable': False,
#    'contains breathless': False,
#    'contains terrible': False,
#    'contains fulfil': False,
#    'contains importantly': False,
#    'contains decorous': False,
#    'contains apparel': False,
#    'contains meth': False,
#    'contains oculus': False,
#    'contains sardius': False,
#    'contains response': False,
#    'contains sleek': False,
#    'contains horridly': False,
#    'contains salutation': False,
#    'contains before': False,
#    'contains autonomy': False,
#    'contains unfold': False,
#    'contains screening': False,
#    'contains helper': False,
#    'contains pizza': False,
#    'contains laughter': False,
#    'contains earnestly': False,
#    'contains align': False,
#    'contains mixologist': False,
#    'contains hastiness': False,
#    'contains coach': False,
#    'contains literate': False,
#    'contains value': False,
#    'contains bankrupt': False,
#    'contains caviare': False,
#    'contains schoolfellow': False,
#    'contains crenation': False,
#    'contains pull': False,
#    'contains motivate': False,
#    'contains veal': False,
#    'contains cargo': False,
#    'contains infrequency': False,
#    'contains jook': False,
#    'contains lilliputian': False,
#    'contains warn': False,
#    'contains eyes': False,
#    'contains volaille': False,
#    'contains hutch': False,
#    'contains mustiness': False,
#    'contains treat': False,
#    'contains recover': False,
#    'contains fixture': False,
#    'contains mitt': False,
#    'contains swain': False,
#    'contains visitor': False,
#    'contains hostess': False,
#    'contains italian': False,
#    'contains significantly': False,
#    'contains session': False,
#    'contains tread': False,
#    'contains gigantic': False,
#    'contains fake': False,
#    'contains mark': False,
#    'contains mare': False,
#    'contains gratuitous': False,
#    'contains remodel': False,
#    'contains adequate': False,
#    'contains specify': False,
#    'contains stagnate': False,
#    'contains refashion': False,
#    'contains daily': False,
#    'contains townspeople': False,
#    'contains schedule': False,
#    'contains addition': False,
#    'contains clip': False,
#    'contains difference': False,
#    'contains commonwealth': False,
#    'contains score': False,
#    'contains serenity': False,
#    'contains order': False,
#    'contains scorn': False,
#    'contains boiler': False,
#    'contains floater': False,
#    'contains special': False,
#    'contains strip': False,
#    'contains arrogate': False,
#    'contains sideboard': False,
#    'contains agency': False,
#    'contains actuate': False,
#    'contains sorrow': False,
#    'contains virgo': False,
#    'contains grow': False,
#    'contains expert': False,
#    'contains ailing': False,
#    'contains learn': False,
#    'contains unequaled': False,
#    'contains stingily': False,
#    'contains establish': False,
#    'contains locating': False,
#    'contains bully': False,
#    'contains rarity': False,
#    'contains cigar': False,
#    'contains watery': False,
#    'contains aspirer': False,
#    'contains warrant': False,
#    'contains hippies': False,
#    'contains groom': False,
#    'contains gratify': False,
#    'contains comic': False,
#    'contains ask': False,
#    'contains snorting': False,
#    'contains inheritance': False,
#    'contains doubtfulness': False,
#    'contains bingle': False,
#    'contains abrupt': False,
#    'contains exist': True,
#    'contains crook': False,
#    'contains sparse': False,
#    'contains audio': False,
#    'contains disappointed': False,
#    'contains cordially': False,
#    'contains invariably': False,
#    'contains acquiring': False,
#    'contains caucasian': False,
#    'contains valse': False,
#    'contains declamatory': False,
#    'contains outcome': False,
#    'contains patronage': False,
#    'contains suffering': False,
#    'contains hype': False,
#    'contains jimmy': False,
#    'contains chips': False,
#    'contains someplace': False,
#    'contains comfortableness': False,
#    'contains customer': False,
#    'contains another': False,
#    'contains joint': False,
#    'contains heedful': False,
#    'contains comportment': False,
#    'contains alternate': False,
#    'contains frightful': False,
#    'contains decor': False,
#    'contains crew': False,
#    'contains manus': False,
#    'contains handed': False,
#    'contains survive': False,
#    'contains attraction': False,
#    'contains picky': False,
#    'contains cook': False,
#    'contains summer': False,
#    'contains power': False,
#    'contains query': False,
#    'contains sinker': False,
#    'contains cool': False,
#    'contains unmanageable': False,
#    'contains convenience': False,
#    'contains pulsation': False,
#    'contains rib': False,
#    'contains responsibility': False,
#    'contains bottleful': False,
#    'contains observation': False,
#    'contains hurriedness': False,
#    'contains melting': False,
#    'contains smiling': False,
#    'contains normal': False,
#    'contains heading': False,
#    'contains elementary': False,
#    'contains towner': False,
#    'contains testament': False,
#    'contains attractor': False,
#    'contains pack': False,
#    'contains piteous': False,
#    'contains inspire': False,
#    'contains shady': False,
#    'contains winner': False,
#    'contains na': False,
#    'contains gnocchi': False,
#    'contains heartily': False,
#    'contains experience': False,
#    'contains nj': False,
#    'contains unconvincing': False,
#    'contains chicness': False,
#    'contains intermediate': False,
#    'contains tasty': False,
#    'contains pertain': False,
#    'contains hideously': False,
#    'contains yeddo': False,
#    'contains boldness': False,
#    'contains jest': False,
#    'contains wannabee': False,
#    'contains malarkey': False,
#    'contains sucker': False,
#    'contains flash': False,
#    'contains stain': False,
#    'contains ground': False,
#    'contains paries': False,
#    'contains township': False,
#    'contains overly': False,
#    'contains taste': False,
#    'contains finis': False,
#    'contains amazing': False,
#    'contains guarantee': False,
#    'contains mouth': False,
#    'contains behave': True,
#    'contains upscale': False,
#    'contains transformation': False,
#    'contains creamy': False,
#    'contains liaise': False,
#    'contains flavor': False,
#    'contains foursquare': False,
#    'contains rhomb': False,
#    'contains nutrient': False,
#    'contains aside': False,
#    'contains saphead': False,
#    'contains ice': False,
#    'contains aesthetic': False,
#    'contains gently': False,
#    'contains noisy': False,
#    'contains substitute': False,
#    'contains clams': False,
#    'contains restate': False,
#    'contains elia': False,
#    'contains randomly': False,
#    'contains animal': False,
#    'contains corona': False,
#    'contains yellowness': False,
#    'contains comparatively': False,
#    'contains style': False,
#    'contains raving': False,
#    'contains stopping': False,
#    'contains clubby': False,
#    'contains readily': False,
#    'contains garden': False,
#    'contains party': False,
#    'contains homelike': False,
#    'contains teenaged': False,
#    'contains gift': False,
#    'contains clothes': False,
#    'contains profits': False,
#    'contains plant': False,
#    'contains duty': False,
#    'contains partly': False,
#    'contains foyer': False,
#    'contains dixieland': False,
#    'contains brainy': False,
#    'contains sashimi': False,
#    'contains endeavor': False,
#    'contains possess': False,
#    'contains open': False,
#    'contains empurple': False,
#    'contains eatable': False,
#    'contains comprise': False,
#    'contains supra': False,
#    'contains postulation': False,
#    'contains enclothe': False,
#    'contains mod': False,
#    'contains eats': False,
#    'contains ostentatious': False,
#    'contains takeaway': False,
#    'contains ticker': False,
#    'contains smash': False,
#    'contains ticket': False,
#    'contains fry': False,
#    'contains remains': False,
#    'contains savouring': False,
#    'contains ahead': False,
#    'contains board': False,
#    'contains admiration': False,
#    'contains jean': False,
#    'contains amoy': False,
#    'contains effects': False,
#    'contains juice': False,
#    'contains square': False,
#    'contains walking': False,
#    'contains hovel': False,
#    'contains duo': False,
#    'contains perfective': False,
#    'contains defy': False,
#    'contains loiter': False,
#    'contains communion': False,
#    'contains high': False,
#    'contains estimate': False,
#    'contains client': False,
#    'contains fold': False,
#    'contains viewing': False,
#    'contains hundred': False,
#    'contains zone': False,
#    'contains folk': False,
#    'contains nearby': False,
#    'contains below': False,
#    'contains vicinity': False,
#    'contains snag': False,
#    'contains pisces': False,
#    'contains perish': False,
#    'contains downstairs': False,
#    'contains indolent': False,
#    'contains morsel': False,
#    'contains destroy': False,
#    'contains watering': False,
#    'contains pink': False,
#    'contains convey': False,
#    'contains meet': False,
#    'contains excuse': False,
#    'contains caprice': False,
#    'contains cabbage': False,
#    'contains patty': False,
#    'contains lonesome': False,
#    'contains casual': False,
#    'contains taiwan': False,
#    'contains gratuity': False,
#    'contains integral': False,
#    'contains indication': False,
#    'contains conserve': False,
#    'contains frankly': False,
#    'contains shaver': False,
#    'contains dissatisfactory': False,
#    'contains things': False,
#    'contains revert': False,
#    'contains tum': False,
#    'contains fashion': False,
#    'contains subtraction': False,
#    'contains topping': False,
#    'contains penny': False,
#    'contains definitive': False,
#    'contains describe': False,
#    'contains puniness': False,
#    'contains bunch': False,
#    'contains eden': False,
#    'contains green': False,
#    'contains unmannerly': True,
#    'contains fashioned': False,
#    'contains calculate': False,
#    'contains likely': False,
#    'contains champion': False,
#    'contains chocolate': False,
#    'contains yellowtail': False,
#    'contains funny': False,
#    'contains jam': False,
#    'contains juncture': False,
#    'contains refuse': False,
#    'contains hut': False,
#    'contains complaint': False,
#    'contains flow': False,
#    'contains hole': False,
#    'contains hold': False,
#    'contains pip': False,
#    'contains enforce': True,
#    'contains carte': False,
#    'contains maine': False,
#    'contains verity': False,
#    'contains bury': False,
#    'contains audience': False,
#    'contains ignition': False,
#    'contains entirely': False,
#    'contains available': False,
#    'contains indorsement': False,
#    'contains telling': False,
#    'contains expect': False,
#    'contains brand': False,
#    'contains heaven': False,
#    'contains vibrant': False,
#    'contains after': False,
#    'contains vegetable': False,
#    'contains scrumptious': False,
#    'contains unbend': False,
#    'contains abode': False,
#    'contains nearly': False,
#    'contains compose': False,
#    'contains dependable': False,
#    'contains flavouring': False,
#    'contains design': False,
#    'contains quibble': False,
#    'contains patron': False,
#    'contains cockeyed': False,
#    'contains whatever': False,
#    'contains marvel': False,
#    'contains flirt': False,
#    'contains esteem': False,
#    'contains waiter': False,
#    'contains wish': True,
#    'contains detest': False,
#    'contains ally': False,
#    'contains barrage': False,
#    'contains introduce': False,
#    'contains divine': False,
#    'contains ciao': False,
#    'contains bounderish': True,
#    'contains debar': False,
#    'contains monish': False,
#    'contains fella': False,
#    'contains endorsement': False,
#    'contains trifle': False,
#    'contains theatre': False,
#    'contains normally': False,
#    'contains concluded': False,
#    'contains doojigger': False,
#    'contains joker': False,
#    ...},
#   u'negative')]

# %% [markdown]
# created train_set test_set broadcast variables

# %%
train_set,test_set= ReviewfRDD.randomSplit([0.8,0.2])
ReviewfRDD.cache()
training_set=sc.broadcast(train_set.collect())
testing_set=sc.broadcast(test_set.collect())

# %% [markdown]
# NaiveBayesClassifier classifier

# %%
NaiveBayesClassifier = nltk.NaiveBayesClassifier.train(training_set.value)

# %%
nltk.classify.accuracy(NaiveBayesClassifier,testing_set.value)
# Out:
# 0.6791044776119403

# %% [markdown]
# Show top 10 informative features

# %%
NaiveBayesClassifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#      contains unmannerly = True           negati : positi =     39.5 : 1.0
#         contains lowbred = True           negati : positi =     39.5 : 1.0
#      contains unmannered = True           negati : positi =     39.5 : 1.0
#            contains rude = True           negati : positi =     39.5 : 1.0
#      contains bounderish = True           negati : positi =     39.5 : 1.0
#           contains grand = True           positi : negati =     14.8 : 1.0
#       contains fantastic = True           positi : negati =     14.8 : 1.0
#             contains ask = True           negati : positi =     13.8 : 1.0
#        contains splendid = True           positi : negati =      9.5 : 1.0
#           contains bland = True           negati : positi =      9.3 : 1.0

# %% [markdown]
# Train MultinomialNB , BernoulliNB Classifier models from sklearn

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB

MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set.value)


BNB_classifier = SklearnClassifier(BernoulliNB())
BNB_classifier.train(training_set.value)
# Out:
# <SklearnClassifier(BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True))>

# %%
print("MultinomialNB accuracy percent:",nltk.classify.accuracy(MNB_classifier, testing_set.value))
print("BernoulliNB accuracy percent:",nltk.classify.accuracy(BNB_classifier, testing_set.value))
# Out:
# MultinomialNB accuracy percent: 0.682835820896
# BernoulliNB accuracy percent: 0.675373134328

# %% [markdown]
# Train RandomForest Classifier models from sklear

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingRegressor
RF_classifier=SklearnClassifier(RandomForestClassifier(n_estimators = 100))
RF_classifier.train(training_set.value)
# Out:
# <SklearnClassifier(RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))>

# %%
pprint("RF_Classifier accuracy is {}".format(nltk.classify.accuracy(RF_classifier,testing_set.value)))
# Out:
# 'RF_Classifier accuracy is 0.649253731343'

# %% [markdown]
# Train LogisticRegression,SGD Classifier models from sklearn

# %%
from sklearn.linear_model import LogisticRegression,SGDClassifier

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set.value)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set.value))*100)

SGDClassifier_classifier = SklearnClassifier(SGDClassifier())
SGDClassifier_classifier.train(training_set.value)
print("SGDClassifier_classifier accuracy percent:", (nltk.classify.accuracy(SGDClassifier_classifier, testing_set.value))*100)
# Out:
# LogisticRegression_classifier accuracy percent: 63.8059701493
# SGDClassifier_classifier accuracy percent: 62.6865671642

# %% [markdown]
# Train SVC,LinearSVC Classifier models from sklear

# %%
from sklearn.svm import SVC, LinearSVC

SVC_classifier = SklearnClassifier(SVC())
SVC_classifier.train(training_set.value)
print("SVC_classifier accuracy percent:", (nltk.classify.accuracy(SVC_classifier, testing_set.value))*100)

LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set.value)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set.value))*100)
# Out:
# SVC_classifier accuracy percent: 61.1940298507
# LinearSVC_classifier accuracy percent: 61.1940298507

# %%
from nltk.classify import ClassifierI
from statistics import mode

# %%
class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers
    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        neg_cnt,pos_cnt=0,0
        for i in votes:
            if i=='negative':
                neg_cnt+=1
            else:
                pos_cnt+=1
        if neg_cnt>pos_cnt:
            return 'negative'
        else:
            return 'positive'
    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf

# %%
voted_classifier = VoteClassifier(NaiveBayesClassifier,
                                  BNB_classifier,
                                  LogisticRegression_classifier,
                                  RF_classifier,
                                  MNB_classifier,
                                  LogisticRegression_classifier,
                                  SGDClassifier_classifier,
                                  LinearSVC_classifier
                                  )

# %%
print("voted_classifier accuracy percent:", (nltk.classify.accuracy(voted_classifier, testing_set.value))*100)

print("Classification:", voted_classifier.classify(testing_set.value[0][0]), "Confidence %:",voted_classifier.confidence(testing_set.value[0][0])*100)
print("Classification:", voted_classifier.classify(testing_set.value[1][0]), "Confidence %:",voted_classifier.confidence(testing_set.value[1][0])*100)
print("Classification:", voted_classifier.classify(testing_set.value[2][0]), "Confidence %:",voted_classifier.confidence(testing_set.value[2][0])*100)
print("Classification:", voted_classifier.classify(testing_set.value[3][0]), "Confidence %:",voted_classifier.confidence(testing_set.value[3][0])*100)
print("Classification:", voted_classifier.classify(testing_set.value[5][0]), "Confidence %:",voted_classifier.confidence(testing_set.value[5][0])*100)
# Out:
# voted_classifier accuracy percent: 63.4328358209
# Classification: positive Confidence %: 100
# Classification: positive Confidence %: 0
# Classification: positive Confidence %: 0
# Classification: positive Confidence %: 0
# Classification: negative Confidence %: 100

# %%
ReviewfRDD.unpersist()
# Out:
# PythonRDD[11] at RDD at PythonRDD.scala:43

# %% [markdown]
# ofile=open('NaiveBayesModel.pickle', 'wb')
# pickle.dump(NaiveBayesClassifier,ofile)

# %% [markdown]
# ofile.close()

# %% [markdown]
# os.listdir('/oasis/projects/nsf/sun116/addankn')

# %%
yelpReviewDF=sqlContext.read.json('hdfs:///yelp_academic_dataset_review.json')

# %%
yelpReviewDF.cache()

yelpReviewDF.select("text").take(1)
yelpReviewDF.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- stars: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- votes: struct (nullable = true)
#  |    |-- cool: long (nullable = true)
#  |    |-- funny: long (nullable = true)
#  |    |-- useful: long (nullable = true)

# %% [markdown]
# #yelpReviewRDD=yelpReviewDF.select("review_id","text").rdd

# %%
yelpReviewRDD=yelpReviewDF.select("review_id","text").limit(100000)
#yelpReviewRDD=yelpReviewDF.select("review_id","text")

# %%
yelpReviewRDD.cache()
yelpReviewRDD.take(2)
# Out:
# [Row(review_id=u'Ya85v4eqdd6k9Od8HbQjyA', text=u'Mr Hoagie is an institution. Walking in, it does seem like a throwback to 30 years ago, old fashioned menu board, booths out of the 70s, and a large selection of food. Their speciality is the Italian Hoagie, and it is voted the best in the area year after year. I usually order the burger, while the patties are obviously cooked from frozen, all of the other ingredients are very fresh. Overall, its a good alternative to Subway, which is down the road.'),
#  Row(review_id=u'KPvLNJ21_4wbYNctrOwWdQ', text=u"Excellent food. Superb customer service. I miss the mario machines they used to have, but it's still a great place steeped in tradition.")]

# %%
def yparse(x):
    y=re.split(r'[^\w]',x)
    #y=[porter.stem(i.lower()) for i in y if len(i) >3 or i=='not']
    y=[i.lower() for i in y if len(i)>3 or i=='not']
    words=[]
    for i in y:
        words.extend(synonyms(i))
    return words

def lowers(x):
    return x.lower()

# %%
yelpReviewpRDD=yelpReviewRDD.map(lambda (x,y):(x,y,yparse(y))).map(lambda (x,z,y):(x,z,list(set(y))))

# %%
wordsb.value[:2]
# Out:
# [u'boilersuit', u'ciao']

# %%
yelpReviewpRDD.cache()
# Out:
# PythonRDD[37] at RDD at PythonRDD.scala:43

# %%
yelpReviewpRDD.take(6)
# Out:
# [(u'Ya85v4eqdd6k9Od8HbQjyA',
#   u'Mr Hoagie is an institution. Walking in, it does seem like a throwback to 30 years ago, old fashioned menu board, booths out of the 70s, and a large selection of food. Their speciality is the Italian Hoagie, and it is voted the best in the area year after year. I usually order the burger, while the patties are obviously cooked from frozen, all of the other ingredients are very fresh. Overall, its a good alternative to Subway, which is down the road.',
#   [u'walking',
#    u'selection',
#    u'boilersuit',
#    u'hamburger',
#    u'years',
#    u'cook',
#    u'alternative',
#    u'bomber',
#    u'menu',
#    u'outflank',
#    u'alternate',
#    u'eld',
#    u'former',
#    u'pile',
#    u'board',
#    u'factor',
#    u'atavistic',
#    u'ingredient',
#    u'identical',
#    u'do',
#    u'patently',
#    u'founding',
#    u'food',
#    u'big',
#    u'spell',
#    u'overall',
#    u'choice',
#    u'early',
#    u'topper',
#    u'declamatory',
#    u'yr',
#    u'down',
#    u'like',
#    u'goodness',
#    u'patch',
#    u'large',
#    u'subway',
#    u'manifestly',
#    u'outdo',
#    u'italian',
#    u'energy',
#    u'freeze',
#    u'burger',
#    u'booth',
#    u'year',
#    u'beefburger',
#    u'best',
#    u'really',
#    u'appear',
#    u'tube',
#    u'forte',
#    u'bracing',
#    u'carte',
#    u'hero',
#    u'component',
#    u'cake',
#    u'element',
#    u'throwback',
#    u'afterward',
#    u'card',
#    u'care',
#    u'piece',
#    u'metro',
#    u'country',
#    u'region',
#    u'ilk',
#    u'commonly',
#    u'pick',
#    u'usually',
#    u'fix',
#    u'road',
#    u'patty',
#    u'suspend',
#    u'afterwards',
#    u'plainly',
#    u'ordination',
#    u'walk',
#    u'peculiarity',
#    u'vote',
#    u'table',
#    u'cubicle',
#    u'hoagy',
#    u'underpass',
#    u'prepare',
#    u'area',
#    u'ordering',
#    u'unremarkably',
#    u'initiation',
#    u'selfsame',
#    u'option',
#    u'brisk',
#    u'kiosk',
#    u'specialty',
#    u'constituent',
#    u'institution',
#    u'underground',
#    u'atavist',
#    u'look',
#    u'wish',
#    u'twelvemonth',
#    u'while',
#    u'stall',
#    u'atavism',
#    u'hoagie',
#    u'route',
#    u'fashion',
#    u'geezerhood',
#    u'speciality',
#    u'sphere',
#    u'good',
#    u'fashioned',
#    u'ready',
#    u'seem',
#    u'obviously',
#    u'metier',
#    u'evidently',
#    u'bombastic',
#    u'strength',
#    u'grinder',
#    u'perform',
#    u'apparently',
#    u'make',
#    u'very',
#    u'other',
#    u'substitute',
#    u'forge',
#    u'establishment',
#    u'reversion',
#    u'class',
#    u'after',
#    u'fresh',
#    u'plank',
#    u'sub',
#    u'refreshing',
#    u'commodity',
#    u'age',
#    u'later',
#    u'ordinarily',
#    u'doe',
#    u'nutrient',
#    u'subsequently',
#    u'normally',
#    u'order']),
#  (u'KPvLNJ21_4wbYNctrOwWdQ',
#   u"Excellent food. Superb customer service. I miss the mario machines they used to have, but it's still a great place steeped in tradition.",
#   [u'outstanding',
#    u'distillery',
#    u'feature',
#    u'hush',
#    u'engulf',
#    u'have',
#    u'apply',
#    u'fantabulous',
#    u'girl',
#    u'still',
#    u'miss',
#    u'engross',
#    u'use',
#    u'service',
#    u'utilize',
#    u'superb',
#    u'machine',
#    u'missy',
#    u'custom',
#    u'plunge',
#    u'bully',
#    u'utilise',
#    u'food',
#    u'absorb',
#    u'spot',
#    u'excellent',
#    u'hold',
#    u'tradition',
#    u'immerse',
#    u'customer',
#    u'great',
#    u'splendid',
#    u'brilliant',
#    u'car',
#    u'misfire',
#    u'experience',
#    u'employ',
#    u'fille',
#    u'stillness',
#    u'client',
#    u'place',
#    u'nutrient',
#    u'property',
#    u'steep']),
#  (u'fFSoGV46Yxuwbr3fHNuZig',
#   u'Yes this place is a little out dated and not opened on the weekend. But other than that the staff is always pleasant and fast to make your order. Which is always spot on fresh veggies on their hoggies and other food. They also have daily specials and ice cream which is really good. I had a banana split they piled the toppings on. They win pennysaver awards ever years i see why.',
#   [u'years',
#    u'invariably',
#    u'staff',
#    u'shuffling',
#    u'eld',
#    u'actually',
#    u'veg',
#    u'spread',
#    u'pile',
#    u'non',
#    u'good',
#    u'food',
#    u'awarding',
#    u'truly',
#    u'early',
#    u'emollient',
#    u'not',
#    u'mob',
#    u'always',
#    u'small',
#    u'see',
#    u'casual',
#    u'special',
#    u'really',
#    u'bracing',
#    u'ever',
#    u'slight',
#    u'honour',
#    u'smudge',
#    u'pleasant',
#    u'besides',
#    u'throng',
#    u'experience',
#    u'place',
#    u'pick',
#    u'honor',
#    u'genuinely',
#    u'shuffle',
#    u'unfold',
#    u'point',
#    u'veggie',
#    u'open',
#    u'little',
#    u'ordering',
#    u'constantly',
#    u'fast',
#    u'too',
#    u'banana',
#    u'brisk',
#    u'award',
#    u'heap',
#    u'hold',
#    u'former',
#    u'property',
#    u'pack',
#    u"e'er",
#    u'geezerhood',
#    u'goodness',
#    u'likewise',
#    u'rip',
#    u'rent',
#    u'have',
#    u'everyday',
#    u'cream',
#    u'make',
#    u'feature',
#    u'also',
#    u'other',
#    u'split',
#    u'vegetable',
#    u'brand',
#    u'topping',
#    u'ointment',
#    u'spot',
#    u'faculty',
#    u'date',
#    u'weekend',
#    u'stack',
#    u'fasting',
#    u'refreshing',
#    u'commodity',
#    u'age',
#    u'daily',
#    u'order',
#    u'accolade',
#    u'fresh',
#    u'nutrient',
#    u'ordination']),
#  (u'pVMIt0a_QsKtuDfWVfSk2A',
#   u'PROS: Italian hoagie was delicious.  Friendly counter employee. The restaurant was clean and neat. \n\nCONS: The pizza was not good.  Pre-formed crust, NOT fresh dough.  The price of the failure of a pizza WAS NOT CHEAP EITHER.  \n\nI guess the name says it all.  Get the hoagie, pass on the pizza.',
#   [u'houseclean',
#    u'cheap',
#    u'supposition',
#    u'dough',
#    u'bunco',
#    u'bomber',
#    u'flash',
#    u'employee',
#    u'friendly',
#    u'non',
#    u'good',
#    u'not',
#    u'bread',
#    u'name',
#    u'loser',
#    u'delightful',
#    u'either',
#    u'speculation',
#    u'italian',
#    u'clams',
#    u'constitute',
#    u'yardbird',
#    u'cost',
#    u'pass',
#    u'terms',
#    u'sub',
#    u'crust',
#    u'boodle',
#    u'state',
#    u'bracing',
#    u'convict',
#    u'flashy',
#    u'hero',
#    u'dinero',
#    u'guess',
#    u'restaurant',
#    u'inexpensive',
#    u'gens',
#    u'pick',
#    u'passing',
#    u'tabulator',
#    u'con',
#    u'organize',
#    u'walk',
#    u'delicious',
#    u'refined',
#    u'hoagy',
#    u'brassy',
#    u'inmate',
#    u'aver',
#    u'tell',
#    u'form',
#    u'brisk',
#    u'incrustation',
#    u'failure',
#    u'eatery',
#    u'favorable',
#    u'neat',
#    u'hoagie',
#    u'counter',
#    u'figure',
#    u'pro',
#    u'conjecture',
#    u'say',
#    u'goodness',
#    u'gall',
#    u'encrustation',
#    u'allege',
#    u'surmise',
#    u'grinder',
#    u'make',
#    u'damage',
#    u'surmisal',
#    u'luscious',
#    u'nonstarter',
#    u'pizza',
#    u'tasteful',
#    u'price',
#    u'buffet',
#    u'professional',
#    u'cabbage',
#    u'refreshing',
#    u'commodity',
#    u'delectable',
#    u'orderly',
#    u'organise',
#    u'clean',
#    u'fresh']),
#  (u'AEyiQ_Y44isJmNbMTyoMKQ',
#   u'First the only reason this place could possibly win best hoagie is because there\'s no competition. Two hoagies and a side of onion rings cost $25.74\n\nSo I\'m thinking with the reader choice awards and $10 per 12" hoagie these will be awesome. \n\nI was sadly mistaken. \n\nThe only reason I didn\'t give one star is because is the bread & dressing is fairly decent. \n\nSo on to the hoagies, the Italian is general run of the mill. Minimal meat and a ton of shredded lettuce. You get more meat at subway. Nothing really special & NOT worthy of the $10 price tag. \n\nSecond, the steak hoagie, it is atrocious. \nNo cheese?!?!? You have to add cheese for $1 so now the steak hoagie is $11. That has so little amounts of meat that I thought I was eating a lettuce & onion hoagie. I am thoroughly disappointed with this hoagie, possibly the worst value of a hoagie I\'ve ever eaten. \nI\'m not say eating at subway is any better, but for the huge price difference you are better off doing so. \nCheck out pasquales down the road, better hoagie & price.',
#   [u'feed',
#    u'selection',
#    u'desirable',
#    u'feature',
#    u'not',
#    u'ever',
#    u'dough',
#    u'reviewer',
#    u'mill',
#    u'bomber',
#    u'jolly',
#    u'ground',
#    u'solitary',
#    u'feeding',
#    u'thinking',
#    u'outflank',
#    u'actually',
#    u'better',
#    u'only',
#    u'punter',
#    u'minute',
#    u'pretty',
#    u'dressing',
#    u'discomfited',
#    u'dispute',
#    u'do',
#    u'non',
#    u'good',
#    u'grievous',
#    u'contention',
#    u'nada',
#    u'toll',
#    u'awarding',
#    u'slight',
#    u'choice',
#    u'possibly',
#    u'worst',
#    u'awful',
#    u'doughnut',
#    u'difference',
#    u'disappointed',
#    u'halo',
#    u'bread',
#    u'deplorably',
#    u'down',
#    u'execute',
#    u'meat',
#    u'onion',
#    u'frustrated',
#    u'reasonably',
#    u'yield',
#    u'honor',
#    u'subway',
#    u'have',
#    u'whip',
#    u'small',
#    u'outdo',
#    u'steak',
#    u'side',
#    u'italian',
#    u'kernel',
#    u'clams',
#    u'spring',
#    u'sensation',
#    u'competition',
#    u'second',
#    u'cost',
#    u'sec',
#    u'measure',
#    u'mayhap',
#    u'terms',
#    u'abominable',
#    u'intellect',
#    u'best',
#    u'really',
#    u'perchance',
#    u'sub',
#    u'tube',
#    u'monstrous',
#    u'rings',
#    u'factory',
#    u'boodle',
#    u'eating',
#    u'reader',
#    u'misidentify',
#    u'misguided',
#    u'minimal',
#    u'core',
#    u'hero',
#    u'bettor',
#    u'fertilization',
#    u'honour',
#    u'sole',
#    u'divergence',
#    u'understanding',
#    u'maven',
#    u'awing',
#    u'reason',
#    u'worthy',
#    u'alone',
#    u'underpass',
#    u'beginning',
#    u'property',
#    u'ace',
#    u'adept',
#    u'route',
#    u'moment',
#    u'experience',
#    u's',
#    u'comely',
#    u'place',
#    u'pick',
#    u'testament',
#    u'dinero',
#    u'suitable',
#    u'think',
#    u'road',
#    u'first',
#    u'chopped',
#    u'cheese',
#    u'outset',
#    u'eat',
#    u'exhaustively',
#    u'moderately',
#    u'vast',
#    u'sliced',
#    u'intellection',
#    u'ring',
#    u'hoagy',
#    u'cerebration',
#    u'little',
#    u'sadly',
#    u'unhappily',
#    u'always',
#    u'decent',
#    u'there',
#    u'lone',
#    u'subscriber',
#    u'immense',
#    u'mentation',
#    u'lamentably',
#    u'pile',
#    u'flagitious',
#    u'more',
#    u'referee',
#    u'consume',
#    u'option',
#    u'becoming',
#    u'award',
#    u'idea',
#    u'substance',
#    u'chit',
#    u'somewhat',
#    u'particular',
#    u'breadstuff',
#    u'hold',
#    u'rivalry',
#    u'peculiar',
#    u'aught',
#    u'metro',
#    u'err',
#    u'mo',
#    u'value',
#    u'will',
#    u'fertilisation',
#    u'sum',
#    u'amount',
#    u'hoagie',
#    u'mistake',
#    u"e'er",
#    u'stuffing',
#    u'underground',
#    u'atrocious',
#    u'springiness',
#    u'give',
#    u'wagerer',
#    u'awesome',
#    u'defeated',
#    u'general',
#    u'minimum',
#    u'slip',
#    u'foiled',
#    u'pip',
#    u'assay',
#    u'null',
#    u'check',
#    u'volition',
#    u'champion',
#    u'huge',
#    u'grinder',
#    u'contest',
#    u'perhaps',
#    u'thoroughly',
#    u'make',
#    u'damage',
#    u'manufactory',
#    u'thither',
#    u'amazing',
#    u'shred',
#    u'special',
#    u'soundly',
#    u'topper',
#    u'disappoint',
#    u'decorous',
#    u'nice',
#    u'deviation',
#    u'fairly',
#    u'star',
#    u'nil',
#    u'shredded',
#    u'price',
#    u'spot',
#    u'lonesome',
#    u'nix',
#    u'peradventure',
#    u'cheeseflower',
#    u'cheque',
#    u'nothing',
#    u'cabbage',
#    u'truly',
#    u'annulus',
#    u'brobdingnagian',
#    u'maybe',
#    u'departure',
#    u'face',
#    u'thought',
#    u'perform',
#    u'accolade',
#    u'fecundation',
#    u'genuinely',
#    u'commencement',
#    u'quantity']),
#  (u'V-bqYx62zpxfH2oFkzXPzw',
#   u'Normally, I do not do reviews of an establishment unless the rating is exceptionally great or exceptionally bad.  If I had not felt sucker punched and mugged after I left Mr. Hoagie, I would not be writing this bad review.  On my first and last trip there, I paid $24.59 for two whole hoagies.  \n\n1) The Italian (ordered because the woman (she) working there told me it was their most popular hoagie) I ordered with lettuce and onions (no tomato, italian dressing which all come free with the hoagie).  I had to pay $1 to add cheese to the hoagie.  Because I was traveling and would not be eating the hoagie right away, I asked for the italian on the side.  She told me there was a charge for the dressing on the side.  I passed on that on principle.  Are you kidding me?  I just saved her money by declining the tomato.  I was not going to pay for the dressing on the side.  At this point, I am certain something is not right and this place appears to me to be in financial trouble.  That pales in comparison to what happened next.  I opened the hoagie and there were three microscopically thin slices of meat on this hoagie.  Ham, salami, and bologna.  Bologna!?!?!?!?    Who in the hell puts disgusting bologna on an Italian hoagie?  That disqualifies that hoagie as an Italian.  The red flags indicating this place is in financial trouble are blinding my view.  One area of this hoagie only had one slice of bologna, no ham and no salami.\n\n2)  The Steak hoagie came with nothing on it but lettuce, tomato, onions, and dressing.  I ordered it without lettuce, tomato, onions, or dressing.  I asked for mayo on the side.  I had to pay for that so I declined.  Are you kidding me?  I just saved them money by passing on the lettuce, tomato, fresh onions, and dressing!  I paid $3 to add saut\xe9ed mushrooms, onions, and cheese.  Here we go again.  Canned mushrooms that were not even cooked through (were still cold) and onions that were still crunchy/undercooked.  News flash:  you need to serve fresh mushrooms that have been saut\xe9ed (canned mushrooms are another sign this place is in financial trouble).  I literally had to open the hoagie to find the steak because I could not taste or see it.  The hoagie was 50% mushrooms, 30%onions, 10% cheese and 10% steak.\n\nI could have personally made 10 whole hoagies with substantial quality ingredients and toppings for the $24.59 I paid for these two whole hoagies.  I intentionally patronize non-chain restaurants to support small businesses.  In this case, Never. Again.  (The hoagie bun was better than average.)  Wake up or you are going to lose your business.',
#   [u'chain',
#    u'mug',
#    u'relieve',
#    u'go',
#    u'bomber',
#    u'feeding',
#    u'equivalence',
#    u'charge',
#    u'blaze',
#    u'dressing',
#    u'microscopically',
#    u'norm',
#    u'ingredient',
#    u'woman',
#    u'cook',
#    u'trouble',
#    u'dim',
#    u'level',
#    u'uncovering',
#    u'eve',
#    u'item',
#    u'small',
#    u'charwoman',
#    u'designedly',
#    u'dilute',
#    u'picket',
#    u'be',
#    u'sign',
#    u'traveling',
#    u'enjoin',
#    u'even',
#    u'appear',
#    u"ne'er",
#    u'worsen',
#    u'boodle',
#    u'perforate',
#    u'thin',
#    u'hero',
#    u'fertilization',
#    u'hera',
#    u'never',
#    u'component',
#    u'punch',
#    u'here',
#    u'alone',
#    u'aftermath',
#    u'great',
#    u'substance',
#    u'exceptionally',
#    u'commonly',
#    u'leaving',
#    u'repel',
#    u'usually',
#    u'flash',
#    u'nauseate',
#    u'put',
#    u'hoagy',
#    u'unit',
#    u'working',
#    u'indispose',
#    u'next',
#    u'comparing',
#    u'tell',
#    u'minor',
#    u'iris',
#    u'brisk',
#    u'flag',
#    u'hold',
#    u'iii',
#    u'word',
#    u'work',
#    u'can',
#    u'following',
#    u'arrive',
#    u'salvage',
#    u'example',
#    u'compare',
#    u'slip',
#    u'give',
#    u'sphere',
#    u'reappraisal',
#    u'want',
#    u'occur',
#    u'legislate',
#    u'travel',
#    u'feature',
#    u'patronize',
#    u'enquire',
#    u'adjacent',
#    u'reject',
#    u'establishment',
#    u'gash',
#    u'mat',
#    u'after',
#    u'spot',
#    u'modest',
#    u'reassessment',
#    u'chump',
#    u'cabbage',
#    u'tomato',
#    u'refuse',
#    u'revolt',
#    u'departure',
#    u'element',
#    u'patronise',
#    u'fecundation',
#    u'eventide',
#    u'subsequently',
#    u'democratic',
#    u'order',
#    u'leftfield',
#    u'blind',
#    u'move',
#    u'befall',
#    u'dough',
#    u'hell',
#    u'cold',
#    u'still',
#    u'solitary',
#    u'womanhood',
#    u'organisation',
#    u'writing',
#    u'better',
#    u'bespeak',
#    u'travelling',
#    u'fool',
#    u'non',
#    u'good',
#    u'3',
#    u'sucker',
#    u'nada',
#    u'not',
#    u'bread',
#    u'personally',
#    u'meat',
#    u'blazing',
#    u'predilection',
#    u'side',
#    u'clams',
#    u'financial',
#    u'distillery',
#    u'reduce',
#    u'breakthrough',
#    u'sponsor',
#    u'happen',
#    u'event',
#    u'semen',
#    u'quality',
#    u'ejaculate',
#    u'jolly',
#    u'evaluation',
#    u'bully',
#    u'tierce',
#    u'free',
#    u'salami',
#    u'formation',
#    u'ask',
#    u'beginning',
#    u'afterward',
#    u'care',
#    u'disqualify',
#    u'place',
#    u'first',
#    u'feed',
#    u'cheese',
#    u'unloose',
#    u'misplace',
#    u'done',
#    u'another',
#    u'open',
#    u'little',
#    u'service',
#    u'bologna',
#    u'indicate',
#    u'inferno',
#    u'serve',
#    u'signaling',
#    u'constituent',
#    u'hoagie',
#    u'institution',
#    u'aught',
#    u'bother',
#    u'future',
#    u'fertilisation',
#    u'outdoors',
#    u'perspective',
#    u'frigidness',
#    u'motivation',
#    u'outstanding',
#    u'wagerer',
#    u'pass',
#    u'ordinarily',
#    u'say',
#    u'seed',
#    u'have',
#    u'need',
#    u'seem',
#    u'null',
#    u'blanch',
#    u'instance',
#    u'blinding',
#    u'topping',
#    u'sure',
#    u'most',
#    u'significant',
#    u'organization',
#    u'nothing',
#    u'masthead',
#    u'unremarkably',
#    u'constitution',
#    u'refreshing',
#    u'clear',
#    u'later',
#    u'face',
#    u'principle',
#    u'liberate',
#    u'away',
#    u'shop',
#    u'rating',
#    u'tidings',
#    u'find',
#    u'occupation',
#    u'gull',
#    u'outside',
#    u'only',
#    u'going',
#    u'disgust',
#    u'factor',
#    u'do',
#    u'get',
#    u'elapse',
#    u'penning',
#    u'yield',
#    u'release',
#    u'through',
#    u'steak',
#    u'frigidity',
#    u'view',
#    u'kernel',
#    u'set',
#    u'aspect',
#    u'fair',
#    u'intelligence',
#    u'unfit',
#    u'close',
#    u'concern',
#    u'advisedly',
#    u'rightfield',
#    u'review',
#    u'state',
#    u'bracing',
#    u'discovery',
#    u'preserve',
#    u'bettor',
#    u'dinero',
#    u'sole',
#    u'job',
#    u'penchant',
#    u'unfold',
#    u'news',
#    u'come',
#    u'last',
#    u'restaurant',
#    u'country',
#    u'region',
#    u'passing',
#    u'whole',
#    u'fix',
#    u'prospect',
#    u'afterwards',
#    u'point',
#    u'character',
#    u'pop',
#    u'matte',
#    u'decline',
#    u'lawsuit',
#    u'create',
#    u'three',
#    u'mark',
#    u'backwash',
#    u'punter',
#    u'mushroom',
#    u'fire',
#    u'dismiss',
#    u'cheeseflower',
#    u'eatery',
#    u'wake',
#    u'demand',
#    u'flashing',
#    u'case',
#    u'look',
#    u'substantial',
#    u'property',
#    u'stuffing',
#    u'almost',
#    u'concatenation',
#    u'evening',
#    u'experience',
#    u'ready',
#    u'grinder',
#    u'inquire',
#    u'pay',
#    u'make',
#    u'pal',
#    u'composition',
#    u'unharmed',
#    u'finish',
#    u'fuss',
#    u'nil',
#    u'banter',
#    u'lonesome',
#    u'nix',
#    u'workings',
#    u'kid',
#    u'off',
#    u'substantive',
#    u'stillness',
#    u'coldness',
#    u'position',
#    u'left',
#    u'unloosen',
#    u'just',
#    u'money',
#    u'salve',
#    u'surpass',
#    u'revaluation',
#    u'cut',
#    u'josh',
#    u'calibre',
#    u'spread',
#    u'deliberately',
#    u'hap',
#    u'cum',
#    u'save',
#    u'real',
#    u'complaint',
#    u'sub',
#    u'mayo',
#    u'displace',
#    u'preference',
#    u'authorship',
#    u'loss',
#    u'onion',
#    u'signal',
#    u'reenforcement',
#    u'lose',
#    u'popular',
#    u'italian',
#    u'right',
#    u'tripper',
#    u'hush',
#    u'caliber',
#    u'hassle',
#    u'flush',
#    u'critique',
#    u'pale',
#    u'slice',
#    u'literally',
#    u'exit',
#    u'core',
#    u'finale',
#    u'eating',
#    u'business',
#    u'pose',
#    u'narrate',
#    u'plug',
#    u'comparison',
#    u'about',
#    u'chaff',
#    u'act',
#    u'threesome',
#    u'outset',
#    u'blench',
#    u'hellhole',
#    u'prepare',
#    u'area',
#    u'support',
#    u'there',
#    u'lone',
#    u'purposely',
#    u'function',
#    u'betoken',
#    u'valuation',
#    u'eat',
#    u'motive',
#    u'mislay',
#    u'reinforcement',
#    u'problem',
#    u'piece',
#    u'average',
#    u'trio',
#    u'taste',
#    u'certain',
#    u'char',
#    u'exist',
#    u'trip',
#    u'again',
#    u'detail',
#    u'patsy',
#    u'thither',
#    u'tin',
#    u'mayonnaise',
#    u'finis',
#    u'conclusion',
#    u'felt',
#    u'equitable',
#    u'fiscal',
#    u'normally',
#    u'rule',
#    u'intentionally',
#    u'fresh',
#    u'commencement'])]

# %%
yelpReviewfRDD=yelpReviewpRDD.map(lambda (x,y,z):(x,y,extract_features(z,wordsb)))

# %%
yelpReviewfRDD.cache()
# Out:
# PythonRDD[39] at RDD at PythonRDD.scala:43

# %%
yelpReviewfRDD.take(1)
# Out:
# [(u'NpkTbM23X8douRPIPletCg',
#   u"My wifey & I decided to venture off of the strip, try something the locals probably do :)\n\nThis is a cute little casino that has Karaoke nights. It is really popular because when we got there & put in our request for a song we wanted to sing it was like a 30 minute wait. Enough to make you a nervous-wreck if you hate waiting. \n\nThe locals there mistaked my friend & I for locals because I guess people don't really venture off the strip. The locals were very welcoming & inviting. I would totally go back here when I go back to Vegas.\n\nNot to mention I got hit on by a lesbian ;) that's a first. Whoa der..... lol.",
#   {'contains sizing': False,
#    'contains sickly': False,
#    'contains frost': False,
#    'contains quaint': False,
#    'contains relatively': False,
#    'contains youngster': False,
#    'contains bungling': False,
#    'contains farewell': False,
#    'contains neighbourhood': False,
#    'contains setback': False,
#    'contains rarified': False,
#    'contains burger': False,
#    'contains attempt': False,
#    'contains houseclean': False,
#    'contains dispatch': False,
#    'contains sangaree': False,
#    'contains honor': False,
#    'contains glorify': False,
#    'contains curry': False,
#    'contains perspective': False,
#    'contains authority': False,
#    'contains invariable': False,
#    'contains viridity': False,
#    'contains starter': False,
#    'contains equitable': False,
#    'contains distillery': False,
#    'contains pry': False,
#    'contains consistent': False,
#    'contains child': False,
#    'contains penchant': False,
#    'contains ego': False,
#    'contains thick': False,
#    'contains hustle': False,
#    'contains okay': False,
#    'contains pro': False,
#    'contains opening': False,
#    'contains visit': False,
#    'contains significant': False,
#    'contains affect': False,
#    'contains desire': True,
#    'contains incorrect': False,
#    'contains notorious': False,
#    'contains dissimilar': False,
#    'contains definitely': False,
#    'contains lady': False,
#    'contains sottish': False,
#    "contains 'tween": False,
#    'contains though': False,
#    'contains marinara': False,
#    'contains clientele': False,
#    'contains hanger': False,
#    'contains plastic': False,
#    'contains prima': False,
#    'contains crave': False,
#    'contains prime': False,
#    'contains postulate': False,
#    'contains reserve': False,
#    'contains talent': False,
#    'contains attention': False,
#    'contains bustle': False,
#    'contains potable': False,
#    'contains month': False,
#    'contains crisp': False,
#    'contains remove': False,
#    'contains liqueur': False,
#    'contains judgement': False,
#    'contains demur': False,
#    'contains jampack': False,
#    'contains evaluate': False,
#    'contains anti': False,
#    'contains courteous': False,
#    'contains commodity': False,
#    'contains surmise': True,
#    'contains scene': False,
#    'contains manager': False,
#    'contains branching': False,
#    'contains interrupt': False,
#    'contains severely': False,
#    'contains forever': False,
#    'contains discreet': False,
#    'contains unostentatious': False,
#    'contains quetch': False,
#    'contains choice': False,
#    'contains blackguard': False,
#    'contains foresee': False,
#    'contains scare': False,
#    'contains suggest': False,
#    'contains alien': False,
#    'contains grin': False,
#    'contains river': False,
#    'contains ramp': False,
#    'contains leon': False,
#    'contains stipulate': False,
#    'contains slop': False,
#    'contains previous': False,
#    'contains patently': False,
#    'contains land': False,
#    'contains belike': True,
#    'contains bakehouse': False,
#    'contains terminated': False,
#    'contains shove': False,
#    'contains testimonial': False,
#    'contains redress': False,
#    'contains xanthous': False,
#    'contains residuum': False,
#    'contains adumbrate': False,
#    'contains newcomer': False,
#    'contains on': False,
#    'contains witness': False,
#    'contains morn': False,
#    'contains enamor': False,
#    'contains grime': False,
#    'contains hush': False,
#    'contains jabber': False,
#    'contains gap': False,
#    'contains deplorably': False,
#    'contains gelatin': False,
#    'contains chichi': False,
#    'contains befall': False,
#    'contains left': False,
#    'contains outing': False,
#    'contains back': True,
#    'contains slice': False,
#    'contains gag': False,
#    'contains dahl': False,
#    'contains digression': False,
#    'contains baluchi': False,
#    'contains drinking': False,
#    'contains negociate': False,
#    'contains valuate': False,
#    'contains stylishness': False,
#    'contains case': False,
#    'contains muddy': False,
#    'contains drop': False,
#    'contains sitting': False,
#    'contains fetid': False,
#    'contains abdomen': False,
#    'contains formulation': False,
#    'contains forestall': False,
#    'contains grounds': False,
#    'contains early': False,
#    'contains overly': False,
#    'contains reeking': False,
#    'contains closer': False,
#    'contains correct': False,
#    'contains seance': False,
#    'contains come': False,
#    'contains asking': True,
#    'contains nix': False,
#    'contains date': False,
#    'contains rubbish': False,
#    'contains plenteous': False,
#    'contains afloat': False,
#    'contains life': False,
#    'contains salesclerk': False,
#    'contains bazaar': False,
#    'contains twine': False,
#    'contains hr': False,
#    'contains devour': False,
#    'contains hipster': False,
#    'contains radius': False,
#    'contains flooded': False,
#    'contains supposition': True,
#    'contains ignition': False,
#    'contains sour': False,
#    'contains employment': False,
#    'contains proceed': False,
#    'contains semi': False,
#    'contains feeling': False,
#    'contains intimately': False,
#    'contains carnal': False,
#    'contains brobdingnagian': False,
#    'contains conveniently': False,
#    'contains pretentious': False,
#    'contains assuredness': False,
#    'contains retell': False,
#    'contains popular': True,
#    'contains washy': False,
#    'contains flawlessness': False,
#    'contains exclude': False,
#    'contains staggeringly': False,
#    'contains quaternion': False,
#    'contains wholly': True,
#    'contains generally': False,
#    'contains lunch': False,
#    'contains ace': False,
#    'contains barkeeper': False,
#    'contains years': False,
#    'contains nevertheless': False,
#    'contains die': False,
#    'contains humus': False,
#    'contains pony': False,
#    'contains filth': False,
#    'contains foretell': False,
#    'contains din': False,
#    'contains act': False,
#    'contains daze': False,
#    'contains sense': False,
#    'contains nowadays': False,
#    'contains ordinarily': False,
#    'contains restrain': False,
#    'contains egg': False,
#    'contains defeated': False,
#    'contains tumble': False,
#    'contains character': False,
#    'contains beingness': False,
#    'contains increase': False,
#    'contains foliage': False,
#    'contains livelihood': False,
#    'contains forfend': False,
#    'contains scoop': False,
#    'contains additional': False,
#    'contains cheeseburger': False,
#    'contains centrist': False,
#    'contains rhombus': False,
#    'contains money': False,
#    'contains unbelievably': False,
#    'contains roof': False,
#    'contains panini': False,
#    'contains coconut': False,
#    'contains poser': False,
#    'contains particular': False,
#    'contains room': False,
#    'contains sushi': False,
#    'contains adjudicate': True,
#    'contains rightfully': False,
#    'contains vomitus': False,
#    'contains eventide': False,
#    'contains fairly': False,
#    'contains execute': False,
#    'contains mightiness': False,
#    'contains balthasar': False,
#    'contains looking': False,
#    'contains affectionate': False,
#    'contains oyster': False,
#    'contains reading': False,
#    'contains regulation': False,
#    'contains stuporous': False,
#    'contains decorative': False,
#    'contains thoroughly': False,
#    'contains chilling': False,
#    'contains potential': False,
#    'contains pilot': False,
#    'contains steal': False,
#    'contains steam': False,
#    'contains attender': False,
#    'contains pace': False,
#    'contains discover': False,
#    'contains particularly': False,
#    'contains miry': False,
#    'contains hat': False,
#    'contains hoummos': False,
#    'contains hap': False,
#    'contains can': False,
#    'contains soothing': False,
#    'contains italy': False,
#    'contains nasty': False,
#    'contains hands': False,
#    'contains barman': False,
#    'contains shutting': False,
#    'contains strange': False,
#    'contains pullulate': False,
#    'contains nothingness': False,
#    'contains pudding': False,
#    'contains roosevelt': False,
#    'contains subtle': False,
#    'contains tribe': False,
#    'contains gimmick': False,
#    'contains diamond': False,
#    'contains yearn': False,
#    'contains innovative': False,
#    'contains chapeau': False,
#    'contains victor': False,
#    'contains dieting': False,
#    'contains apply': False,
#    'contains mash': False,
#    'contains current': False,
#    'contains thirsty': False,
#    'contains modishness': False,
#    'contains aboveboard': False,
#    'contains campaign': False,
#    'contains inducing': False,
#    'contains chicken': False,
#    'contains acknowledge': False,
#    'contains entail': False,
#    'contains immaculate': False,
#    'contains forthwith': False,
#    'contains balochi': False,
#    'contains truly': True,
#    'contains existent': False,
#    'contains confront': False,
#    'contains fete': False,
#    'contains helping': False,
#    'contains rendering': False,
#    'contains wrong': False,
#    'contains cambridge': False,
#    'contains conjecture': True,
#    'contains converge': False,
#    'contains complete': False,
#    'contains speedily': False,
#    'contains pursuit': False,
#    'contains dearest': False,
#    'contains exaggerated': False,
#    'contains cut': False,
#    'contains already': False,
#    'contains very': True,
#    'contains decease': False,
#    'contains carnival': False,
#    'contains give': False,
#    'contains smelly': False,
#    'contains blanket': False,
#    'contains pile': False,
#    'contains overlook': False,
#    'contains afters': False,
#    'contains slack': False,
#    'contains bar': False,
#    'contains mussitation': False,
#    'contains jurist': False,
#    'contains maize': False,
#    'contains closing': False,
#    'contains costless': False,
#    'contains ovolo': False,
#    'contains apologize': False,
#    'contains warmly': False,
#    'contains kick': False,
#    'contains bad': False,
#    'contains slenderly': False,
#    'contains modification': False,
#    'contains pluck': False,
#    'contains exhibit': False,
#    'contains recognise': False,
#    'contains unquestionable': False,
#    'contains several': False,
#    'contains downtown': False,
#    'contains elsewhere': False,
#    'contains fall': False,
#    'contains broadly': False,
#    'contains hubby': False,
#    'contains toppingly': False,
#    'contains malodour': False,
#    'contains hone': False,
#    'contains drill': False,
#    'contains thai': False,
#    'contains dressing': False,
#    'contains thaw': False,
#    'contains untempting': False,
#    'contains disc': False,
#    'contains bid': True,
#    'contains overprice': False,
#    'contains mussy': False,
#    'contains mascarpone': False,
#    'contains speed': False,
#    'contains solution': False,
#    'contains chennai': False,
#    'contains resemble': False,
#    'contains exotic': False,
#    'contains balthazar': False,
#    'contains launch': False,
#    'contains fashioning': False,
#    'contains chintzily': False,
#    'contains stoppage': False,
#    "contains abc's": False,
#    'contains conditions': False,
#    'contains clam': False,
#    'contains creative': False,
#    'contains enliven': False,
#    'contains sentience': False,
#    'contains consolation': False,
#    'contains nightdress': False,
#    'contains hang': False,
#    'contains adorable': False,
#    'contains celebrate': False,
#    'contains hand': False,
#    'contains master': False,
#    'contains arrant': False,
#    'contains standard': False,
#    'contains newly': False,
#    'contains allergy': False,
#    'contains disengagement': False,
#    'contains derisory': False,
#    'contains costly': False,
#    'contains terrine': False,
#    'contains certainly': False,
#    'contains emetic': False,
#    'contains siam': False,
#    'contains self': False,
#    'contains hapless': False,
#    'contains stop': False,
#    'contains comfy': False,
#    'contains heaving': False,
#    'contains sauce': False,
#    'contains put': False,
#    'contains push': False,
#    'contains seeking': False,
#    'contains bodoni': False,
#    'contains assortment': False,
#    'contains awkward': False,
#    'contains 1000': False,
#    'contains pud': False,
#    'contains view': False,
#    'contains edo': False,
#    'contains bunk': False,
#    'contains diminutive': False,
#    'contains solidness': False,
#    'contains unsmooth': False,
#    'contains overstep': False,
#    'contains glow': False,
#    'contains abcs': False,
#    'contains relieve': False,
#    'contains madras': False,
#    'contains tagliatelle': False,
#    'contains avowedly': False,
#    'contains older': False,
#    'contains mentum': False,
#    'contains outflank': False,
#    'contains poor': False,
#    'contains fairish': False,
#    'contains furnish': False,
#    'contains rapid': False,
#    'contains bleary': False,
#    'contains desk': False,
#    'contains vacation': False,
#    'contains point': False,
#    'contains stallion': False,
#    'contains possessor': False,
#    'contains lower': False,
#    'contains folks': False,
#    'contains afternoon': False,
#    'contains moreover': False,
#    'contains weird': False,
#    'contains naan': False,
#    'contains sometime': False,
#    'contains drunken': False,
#    'contains venter': False,
#    'contains breath': False,
#    'contains band': False,
#    'contains bang': False,
#    'contains tiddly': False,
#    'contains eye': False,
#    'contains sard': False,
#    'contains brassiere': False,
#    'contains forenoon': False,
#    'contains downstair': False,
#    'contains hunt': False,
#    'contains least': False,
#    'contains infelicitous': False,
#    'contains story': False,
#    'contains mutter': False,
#    'contains store': False,
#    'contains hudson': False,
#    'contains jigger': False,
#    'contains condition': False,
#    'contains storm': False,
#    'contains lease': False,
#    'contains cramp': False,
#    'contains folio': False,
#    'contains creepy': False,
#    'contains scary': False,
#    'contains reckoning': False,
#    'contains composition': False,
#    'contains incline': False,
#    'contains insert': False,
#    'contains encounter': False,
#    'contains messy': False,
#    'contains grill': False,
#    'contains respect': False,
#    'contains sashay': False,
#    'contains sadly': False,
#    'contains dorsum': True,
#    'contains defeat': False,
#    'contains funfair': False,
#    'contains suspicious': False,
#    'contains malarky': False,
#    'contains cognise': False,
#    'contains smart': False,
#    'contains squid': False,
#    'contains sofa': False,
#    'contains ballyhoo': False,
#    'contains assure': False,
#    'contains blackfriar': False,
#    'contains improver': False,
#    'contains stooge': False,
#    'contains soft': False,
#    'contains westward': False,
#    'contains glad': False,
#    'contains require': True,
#    'contains tramp': False,
#    'contains indoor': False,
#    'contains kiosk': False,
#    'contains violative': False,
#    'contains inhabit': False,
#    'contains territory': False,
#    'contains vanilla': False,
#    'contains postponement': True,
#    'contains trace': False,
#    'contains first': True,
#    'contains split': False,
#    'contains victuals': False,
#    'contains gripe': False,
#    'contains reliable': False,
#    'contains larger': False,
#    'contains steamer': False,
#    'contains squash': False,
#    'contains swerve': False,
#    'contains wrap': False,
#    'contains any': False,
#    'contains portion': False,
#    'contains hombre': False,
#    'contains missy': False,
#    'contains dinner': False,
#    'contains intimate': False,
#    'contains hasten': False,
#    'contains small': True,
#    'contains filling': False,
#    'contains sticky': False,
#    'contains truthful': False,
#    'contains advanced': False,
#    'contains confederacy': False,
#    'contains veto': False,
#    'contains embark': True,
#    'contains fantastical': False,
#    'contains utter': False,
#    'contains wheresoever': False,
#    'contains histrion': False,
#    'contains girl': False,
#    'contains intercede': False,
#    'contains simpleton': False,
#    'contains fiber': False,
#    'contains cuisine': False,
#    'contains outdoors': False,
#    'contains os': False,
#    'contains model': False,
#    'contains bind': False,
#    'contains kuki': False,
#    'contains consume': False,
#    'contains getting': False,
#    'contains elia': False,
#    'contains decompress': False,
#    'contains insure': False,
#    'contains planet': False,
#    'contains each': False,
#    'contains kill': False,
#    'contains flashy': False,
#    'contains rip': False,
#    'contains appetizer': False,
#    'contains positioning': False,
#    'contains measure': False,
#    'contains ok': False,
#    'contains late': False,
#    'contains floor': False,
#    'contains semitrailer': False,
#    'contains instill': False,
#    'contains satisfy': False,
#    'contains methamphetamine': False,
#    'contains return': False,
#    'contains impose': False,
#    'contains cognisant': False,
#    'contains hatred': True,
#    'contains crossways': False,
#    'contains assess': False,
#    'contains tryout': False,
#    'contains direction': False,
#    'contains accentuate': False,
#    'contains antechamber': False,
#    'contains reek': False,
#    'contains monstrously': False,
#    'contains tomorrow': False,
#    'contains overtone': False,
#    'contains instantly': False,
#    'contains gladiola': False,
#    'contains fussy': False,
#    'contains somebody': False,
#    'contains reverse': False,
#    'contains becoming': False,
#    'contains apprehensible': False,
#    'contains devotee': False,
#    'contains despite': False,
#    'contains decide': True,
#    'contains aware': False,
#    'contains infuse': False,
#    'contains purchase': False,
#    'contains need': True,
#    'contains hitch': False,
#    'contains usable': False,
#    'contains comrade': False,
#    'contains affordable': False,
#    'contains perplex': False,
#    'contains authentically': False,
#    'contains salmon': False,
#    'contains sudor': False,
#    'contains absurdly': False,
#    'contains hiking': False,
#    'contains corset': False,
#    'contains win': False,
#    'contains crenature': False,
#    'contains gain': False,
#    'contains coalition': False,
#    'contains bra': False,
#    'contains unlikely': False,
#    'contains brewery': False,
#    'contains wintertime': False,
#    'contains partake': False,
#    'contains plain': False,
#    'contains surprising': False,
#    'contains apropos': False,
#    'contains fatigue': False,
#    'contains occurrence': False,
#    'contains preference': False,
#    'contains reasonable': False,
#    'contains breathless': False,
#    'contains terrible': False,
#    'contains fulfil': False,
#    'contains importantly': False,
#    'contains decorous': False,
#    'contains apparel': False,
#    'contains family': False,
#    'contains meth': False,
#    'contains oculus': False,
#    'contains sardius': False,
#    'contains response': False,
#    'contains appear': False,
#    'contains salutation': False,
#    'contains before': False,
#    'contains emcee': False,
#    'contains levy': False,
#    'contains tend': False,
#    'contains screening': False,
#    'contains helper': False,
#    'contains pizza': False,
#    'contains laughter': False,
#    'contains vinegar': False,
#    'contains align': False,
#    'contains mixologist': False,
#    'contains hastiness': False,
#    'contains coach': False,
#    'contains literate': False,
#    'contains value': False,
#    'contains bankrupt': False,
#    'contains divinity': False,
#    'contains schoolfellow': False,
#    'contains crenation': False,
#    'contains capsicum': False,
#    'contains appeal': False,
#    'contains veal': False,
#    'contains cargo': False,
#    'contains infrequency': False,
#    'contains jook': False,
#    'contains lilliputian': False,
#    'contains savor': False,
#    'contains eyes': False,
#    'contains volaille': False,
#    'contains hutch': False,
#    'contains mustiness': False,
#    'contains occupy': False,
#    'contains recover': False,
#    'contains fixture': False,
#    'contains mitt': False,
#    'contains swain': False,
#    'contains visitor': False,
#    'contains hostess': False,
#    'contains indigene': False,
#    'contains significantly': False,
#    'contains session': False,
#    'contains tread': False,
#    'contains gigantic': False,
#    'contains fake': False,
#    'contains mark': False,
#    'contains mare': False,
#    'contains gratuitous': False,
#    'contains remodel': False,
#    'contains adequate': True,
#    'contains gentleman': False,
#    'contains specify': False,
#    'contains stagnate': False,
#    'contains refashion': False,
#    'contains daily': False,
#    'contains society': False,
#    'contains bribe': False,
#    'contains addition': False,
#    'contains post': False,
#    'contains tattily': False,
#    'contains difference': False,
#    'contains commonwealth': False,
#    'contains score': False,
#    'contains board': False,
#    'contains scorn': False,
#    'contains boiler': False,
#    'contains floater': False,
#    'contains strip': True,
#    'contains arrogate': False,
#    'contains sideboard': False,
#    'contains agency': False,
#    'contains actuate': False,
#    'contains sorrow': False,
#    'contains doi': False,
#    'contains virgo': False,
#    'contains grow': False,
#    'contains expert': False,
#    'contains ailing': False,
#    'contains learn': False,
#    'contains unequaled': False,
#    'contains stingily': False,
#    'contains establish': False,
#    'contains locating': False,
#    'contains bully': False,
#    'contains rarity': False,
#    'contains heights': False,
#    'contains aspirer': False,
#    'contains warrant': False,
#    'contains hippies': False,
#    'contains groom': False,
#    'contains gratify': False,
#    'contains comic': False,
#    'contains ask': False,
#    'contains snorting': False,
#    'contains inheritance': False,
#    'contains doubtfulness': False,
#    'contains bingle': False,
#    'contains nan': False,
#    'contains exist': True,
#    'contains crook': False,
#    'contains sparse': False,
#    'contains moody': False,
#    'contains disappointed': False,
#    'contains cordially': False,
#    'contains plunder': False,
#    'contains translation': False,
#    'contains acquiring': False,
#    'contains caucasian': False,
#    'contains lasagne': False,
#    'contains outcome': False,
#    'contains lasagna': False,
#    'contains suffering': False,
#    'contains hype': False,
#    'contains jimmy': False,
#    'contains chips': False,
#    'contains dealings': False,
#    'contains someplace': False,
#    'contains comfortableness': False,
#    'contains customer': False,
#    'contains another': False,
#    'contains terrace': False,
#    'contains heedful': False,
#    'contains comportment': False,
#    'contains misfire': False,
#    'contains humous': False,
#    'contains decor': False,
#    'contains diverge': False,
#    'contains crew': False,
#    'contains manus': False,
#    'contains handed': False,
#    'contains attraction': False,
#    'contains cook': False,
#    'contains summer': False,
#    'contains power': False,
#    'contains query': False,
#    'contains sinker': False,
#    'contains cool': False,
#    'contains unmanageable': False,
#    'contains convenience': False,
#    'contains pulsation': False,
#    'contains bottleful': False,
#    'contains observation': False,
#    'contains hurriedness': False,
#    'contains melting': False,
#    'contains smiling': False,
#    'contains normal': False,
#    'contains heading': False,
#    'contains elementary': False,
#    'contains towner': False,
#    'contains testament': False,
#    'contains howling': False,
#    'contains pack': False,
#    'contains piteous': False,
#    'contains inspire': False,
#    'contains shady': False,
#    'contains winner': False,
#    'contains na': False,
#    'contains gnocchi': False,
#    'contains heartily': False,
#    'contains supra': False,
#    'contains nj': False,
#    'contains unconvincing': False,
#    'contains chicness': False,
#    'contains unwind': False,
#    'contains intermediate': False,
#    'contains tasty': False,
#    'contains pertain': False,
#    'contains helpful': False,
#    'contains yeddo': False,
#    'contains someways': False,
#    'contains jest': False,
#    'contains wannabee': False,
#    'contains malarkey': False,
#    'contains sucker': False,
#    'contains flash': False,
#    'contains stain': False,
#    'contains ground': False,
#    'contains paries': False,
#    'contains unattractive': False,
#    'contains accession': False,
#    'contains taste': False,
#    'contains amazing': False,
#    'contains guarantee': False,
#    'contains mouth': False,
#    'contains behave': False,
#    'contains upscale': False,
#    'contains transformation': False,
#    'contains eats': False,
#    'contains liaise': False,
#    'contains flavor': False,
#    'contains foursquare': False,
#    'contains perchance': False,
#    'contains ranch': False,
#    'contains aside': False,
#    'contains saphead': False,
#    'contains ice': False,
#    'contains aesthetic': False,
#    'contains gently': False,
#    'contains noisy': False,
#    'contains boom': False,
#    'contains junket': False,
#    'contains substitute': False,
#    'contains clams': False,
#    'contains restate': False,
#    'contains randomly': False,
#    'contains animal': False,
#    'contains round': False,
#    'contains corona': False,
#    'contains earmark': False,
#    'contains yellowness': False,
#    'contains comparatively': False,
#    'contains husband': False,
#    'contains earnestly': False,
#    'contains raving': False,
#    'contains stopping': False,
#    'contains clubby': False,
#    'contains bitterness': False,
#    'contains readily': False,
#    'contains garden': False,
#    'contains china': False,
#    'contains homelike': False,
#    'contains gift': False,
#    'contains clothes': False,
#    'contains mayo': False,
#    'contains plant': False,
#    'contains duty': False,
#    'contains partly': False,
#    'contains foyer': False,
#    'contains brainy': False,
#    'contains sashimi': False,
#    'contains lacking': False,
#    'contains possess': False,
#    'contains open': False,
#    'contains empurple': False,
#    'contains comprise': False,
#    'contains heed': False,
#    'contains experience': False,
#    'contains postulation': True,
#    'contains enclothe': False,
#    'contains mod': False,
#    'contains creamy': False,
#    'contains ostentatious': False,
#    'contains takeaway': False,
#    'contains ticker': False,
#    'contains smash': False,
#    'contains ticket': False,
#    'contains remains': False,
#    'contains savouring': False,
#    'contains moment': True,
#    'contains jean': False,
#    'contains amoy': False,
#    'contains broil': False,
#    'contains edible': False,
#    'contains gratuity': False,
#    'contains luncheon': False,
#    'contains afterward': False,
#    'contains duo': False,
#    'contains perfective': False,
#    'contains defy': False,
#    'contains loiter': False,
#    'contains communion': False,
#    'contains maine': False,
#    'contains estimate': False,
#    'contains impeccable': False,
#    'contains fold': False,
#    'contains viewing': False,
#    'contains hundred': False,
#    'contains growth': False,
#    'contains folk': False,
#    'contains nearby': False,
#    'contains below': False,
#    'contains vicinity': False,
#    'contains snag': False,
#    'contains pisces': False,
#    'contains perish': False,
#    'contains downstairs': False,
#    'contains indolent': False,
#    'contains writing': False,
#    'contains morsel': False,
#    'contains destroy': False,
#    'contains watering': False,
#    'contains pink': False,
#    'contains convey': False,
#    'contains meet': False,
#    'contains legion': False,
#    'contains caprice': False,
#    'contains cabbage': False,
#    'contains patty': False,
#    'contains lonesome': False,
#    'contains casual': False,
#    'contains taiwan': False,
#    'contains square': False,
#    'contains uncomfortable': False,
#    'contains integral': False,
#    'contains indication': False,
#    'contains conserve': False,
#    'contains frankly': False,
#    'contains shaver': False,
#    'contains institution': False,
#    'contains things': False,
#    'contains revert': False,
#    'contains tum': False,
#    'contains fashion': False,
#    'contains subtraction': False,
#    'contains topping': False,
#    'contains penny': False,
#    'contains definitive': False,
#    'contains describe': False,
#    'contains puniness': False,
#    'contains dicker': False,
#    'contains bunch': False,
#    'contains eden': False,
#    'contains green': False,
#    'contains unmannerly': False,
#    'contains credit': True,
#    'contains likely': True,
#    'contains take': False,
#    'contains champion': False,
#    'contains chocolate': False,
#    'contains yellowtail': False,
#    'contains funny': False,
#    'contains jam': False,
#    'contains snap': False,
#    'contains drippy': False,
#    'contains sally': False,
#    'contains someway': False,
#    'contains flow': False,
#    'contains hole': False,
#    'contains hold': True,
#    'contains pip': False,
#    'contains enforce': False,
#    'contains carte': False,
#    'contains confab': False,
#    'contains bury': False,
#    'contains audience': False,
#    'contains soup': False,
#    'contains entirely': True,
#    'contains available': False,
#    'contains indorsement': False,
#    'contains telling': False,
#    'contains expect': True,
#    'contains brand': True,
#    'contains burn': False,
#    'contains vibrant': False,
#    'contains after': False,
#    'contains vegetable': False,
#    'contains scrumptious': False,
#    'contains unbend': False,
#    'contains abode': False,
#    'contains nearly': False,
#    'contains overdo': False,
#    'contains compose': False,
#    'contains solid': False,
#    'contains research': False,
#    'contains design': False,
#    'contains quibble': False,
#    'contains patron': False,
#    'contains cockeyed': False,
#    'contains whatever': False,
#    'contains marvel': False,
#    'contains flirt': False,
#    'contains esteem': False,
#    'contains waiter': False,
#    'contains wish': True,
#    'contains detest': True,
#    'contains district': False,
#    'contains dwelling': False,
#    'contains barrage': False,
#    'contains introduce': False,
#    'contains divine': False,
#    'contains ciao': False,
#    'contains bounderish': False,
#    'contains smile': False,
#    'contains monish': False,
#    'contains fella': False,
#    'contains endorsement': False,
#    'contains trifle': False,
#    'contains theatre': False,
#    'contains normally': False,
#    ...})]

# %%
yelpReviewcRDD=yelpReviewfRDD.map(lambda (x,z,y):(str(x),z,str(NaiveBayesClassifier.classify(y)),str(RF_classifier.classify(y)),                                                
                                              str(BNB_classifier.classify(y)),
                                              str(LogisticRegression_classifier.classify(y)),
                                              str(MNB_classifier.classify(y)),
                                              str(SGDClassifier_classifier.classify(y)),
                                              str(LinearSVC_classifier.classify(y)),
                                                str(voted_classifier.classify(y))))

# %%
yelpReviewcRDD.cache()
# Out:
# PythonRDD[40] at RDD at PythonRDD.scala:43

# %%
pprint(yelpReviewcRDD.take(3))

# %%
type(yelpReviewcRDD)
hasattr(yelpReviewcRDD, "toDF")
# Out:
# True

# %%
yelpReviewcDF2=yelpReviewcRDD.toDF()

# %%
yelpReviewcDF2.printSchema()
# Out:
# root
#  |-- _1: string (nullable = true)
#  |-- _2: string (nullable = true)
#  |-- _3: string (nullable = true)
#  |-- _4: string (nullable = true)
#  |-- _5: string (nullable = true)
#  |-- _6: string (nullable = true)
#  |-- _7: string (nullable = true)
#  |-- _8: string (nullable = true)
#  |-- _9: string (nullable = true)
#  |-- _10: string (nullable = true)

# %%
yelpReviewcDF2.show(1)
# Out:
# +--------------------+--------------------+--------+--------+--------+--------+--------+--------+--------+--------+
# |                  _1|                  _2|      _3|      _4|      _5|      _6|      _7|      _8|      _9|     _10|
# +--------------------+--------------------+--------+--------+--------+--------+--------+--------+--------+--------+
# |NpkTbM23X8douRPIP...|My wifey & I deci...|negative|negative|negative|negative|negative|negative|negative|negative|
# +--------------------+--------------------+--------+--------+--------+--------+--------+--------+--------+--------+
# only showing top 1 row

# %%
yelpReviewcDF2=yelpReviewcDF2.selectExpr("_1 as ReviewId","_2 as text","_3 as NaiveBayes", "_4 as RFClassification" ,"_5 as BNBClassification "
                ,"_6 as LogisticRegressionClassification", "_7 as MNBClassification" ,
                "_8 as SGDClassification",  "_9 as LinearSVCClassification", "_10 as CombinedClassification")

# %%
yelpReviewcDF2.printSchema()
# Out:
# root
#  |-- ReviewId: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- NaiveBayes: string (nullable = true)
#  |-- RFClassification: string (nullable = true)
#  |-- BNBClassification: string (nullable = true)
#  |-- LogisticRegressionClassification: string (nullable = true)
#  |-- MNBClassification: string (nullable = true)
#  |-- SGDClassification: string (nullable = true)
#  |-- LinearSVCClassification: string (nullable = true)
#  |-- CombinedClassification: string (nullable = true)

# %%
yelpReviewcDF2.show(3)
# Out:
# +--------------------+--------------------+----------+----------------+-----------------+--------------------------------+-----------------+-----------------+-----------------------+----------------------+
# |            ReviewId|                text|NaiveBayes|RFClassification|BNBClassification|LogisticRegressionClassification|MNBClassification|SGDClassification|LinearSVCClassification|CombinedClassification|
# +--------------------+--------------------+----------+----------------+-----------------+--------------------------------+-----------------+-----------------+-----------------------+----------------------+
# |NpkTbM23X8douRPIP...|My wifey & I deci...|  negative|        negative|         negative|                        negative|         negative|         negative|               negative|              negative|
# |Dcn7SHEyUN5BDalaU...|Beer is awesome! ...|  negative|        negative|         negative|                        negative|         negative|         negative|               negative|              negative|
# |2URAUtCMjMzFJhMkT...|Every time we com...|  positive|        positive|         positive|                        positive|         positive|         positive|               positive|              positive|
# +--------------------+--------------------+----------+----------------+-----------------+--------------------------------+-----------------+-----------------+-----------------------+----------------------+
# only showing top 3 rows

# %%
#yelpReviewcDF2.rdd.saveAsTextFile("file:///home/addankn/out.txt")

# %%
yelpReviewPD=yelpReviewcDF2.toPandas()

# %%
type(yelpReviewPD)
# Out:
# pandas.core.frame.DataFrame

# %%
yelpReviewPD
# Out:
#                     ReviewId  \
# 0     NpkTbM23X8douRPIPletCg
# 1     Dcn7SHEyUN5BDalaUDc-6g
# 2     2URAUtCMjMzFJhMkTpMnLA
# 3     hoiHUrd2csfiiqKVlaVWbw
# 4     zAx6l2nsW19ZmqLiAEP29w
# 5     kaz0xlmj-72GGd-_kAJDWQ
# 6     7YBQ6YkKw7IiRAIbwAhRIg
# 7     BUMGO2QBIXcOm3Jh1Nd6mQ
# 8     5SLkvG5RV0qJnh9ZLGS9Ww
# 9     _-MdgspEO1dAxgKxtOAnSA
# 10    P4zCpGoP473DTZjcF0NAUA
# 11    JKZmUsfZVbvBtpSj_0aPbQ
# 12    PAI548rpmgEFPLppbWqSww
# 13    E156CBUx06FquGo4Tv9C3w
# 14    HrMLtr-abtTkMZGlY7em3A
# 15    KaHEOgM586_b32IUdi2P9g
# 16    gt8kaP-X8hd70P2x9a8YkQ
# 17    N5vD_8_f27lyIbfJZeuW0g
# 18    JAyE4B17G4RtMu2ADZ_ksA
# 19    HcJE8YFqz4QviE7IT7k1zg
# 20    cmggddZGPg4H_qJ6R-SJVQ
# 21    uuiyzkCVHRfCzecentM_wQ
# 22    M-k2ryzIZRr8HwJRZRezyQ
# 23    EQApX8wFUoRJjQsh-HuSTg
# 24    xnopC325H_Gfkd8Tk5W3sw
# 25    j1o183sQPw7P_PDaDWvbGQ
# 26    rRgSLSluhx_yTkH1i65TXQ
# 27    PQfYi-2UwYBPGQcZw72NuQ
# 28    4xd_Rsyo3KXrvL_Ac_WTwA
# 29    X2rgeMhio5AqN8CILeeTuw
# ...                      ...
# 9970  r_Cue3xwUcieIeM3GtCnwg
# 9971  hrrouo3u-7jHEQrfkpHYtA
# 9972  bfCVg2dCTgcBGv3Km_Uwbw
# 9973  6PpJUEIbWItYL4ZlwjFLQQ
# 9974  exIVSV8H76hZ7zbvFI_azQ
# 9975  SXetRId0sZ8FPWwIBeeSdw
# 9976  H8Xr6UctJUEY70tUPNuwDg
# 9977  coMPkWVtWFy1JS86bXQmPQ
# 9978  CPrzgDniazVqukZflWNOmQ
# 9979  1D6h2v8U-WZ8M4ZXmae3pA
# 9980  c_8OvQP4CdVhd10WkvWVsQ
# 9981  NxcjvCC1k2audXKt0HniJw
# 9982  RfdHBp8s1EMRjtT4RSUuvA
# 9983  mDQVpc03w5KLm-go-YlZ1g
# 9984  diGvoz5bEBvwLLN6mfzVQg
# 9985  Am0BCdcvBWGRev96MDuB5g
# 9986  bXd92FF-o93BlGLB_Pa-TA
# 9987  laeF18HocV0_oCZu3IAXjw
# 9988  Zm08wcep2F-nRTHRyR8mpw
# 9989  4pZQIJO72n0YiaNZkGBKMw
# 9990  BlYlIG4mwV3jSMSQOutkTA
# 9991  leqiwxYsgsifCbLXv9aDEQ
# 9992  lo_YOdpMhXDbi1y7Tsx4WQ
# 9993  cVgGqdME5NFehARjhRf2Tg
# 9994  RjZEOXRqVyu_lIX4pYYtsg
# 9995  v1BKgtCuTl-JAkAf7lXHEA
# 9996  weA6iK0qialyO8zKaaD-6w
# 9997  KxOk_C6xQg1kweZEY3Cjyw
# 9998  8HjLM0PmfeIhhBd4nGj84w
# 9999  LnimzdXlFbDgH09QgBdCAA
#
#                                                    text  \
# 0     My wifey & I decided to venture off of the str...
# 1     Beer is awesome! Food is a russian roulette! S...
# 2     Every time we come to Vegas this is the 1st pl...
# 3     what a find this place was , had the steak spe...
# 4     FREAKING LOVE THIS PLACE.\n\nHave gone here ev...
# 5     We were referred by a friend and I must say if...
# 6     The parking sucks but besides that this place ...
# 7     This place is AWESOME!!! I've been hearing abo...
# 8     So I'm staying at the Holiday Inn off the stri...
# 9     Wow this place is fun!  The beer is good and t...
# 10    What the hell happened Ellis Island!\n\nMy fir...
# 11    Ellis Island Casino is an old school casino th...
# 12    Love the ribs here. Gotta arrive early to put ...
# 13    The food is awesome at some very reasonable pr...
# 14    If your looking for a diamond in the rough, th...
# 15    Several years ago a cab driver told us about E...
# 16    Haven't eaten at Ellis Island, so this review ...
# 17    Always my first stop in Vegas. I usually catch...
# 18    Great place for cheap beer and its brewed ther...
# 19    This place is an absolute MUST whenever I'm in...
# 20    Went here over the weekend. Heard great things...
# 21    The must visit restaurant when you come to Las...
# 22    It's a place for late night cheap meals but th...
# 23    This place was close to my hotel and I went he...
# 24    cheap but not worth a long wait, had the prime...
# 25    This is always a must stop by spot for me ever...
# 26    On my annual roadtrip to Vegas with my family ...
# 27    Steak and eggs !!! It took a while to get our ...
# 28    The hole-in-wall of a wall with many, many hol...
# 29    Some of my girlfriends coworkers recently invi...
# ...                                                 ...
# 9970  Let me just start by saying that the only reas...
# 9971  A dinner date here is always sets the right mo...
# 9972  Wolfgang Puck's establishment at The Venetian ...
# 9973  I struggled with this rating.\r\nWe were told ...
# 9974  decent casino restaurant from the wolfgang puc...
# 9975  Calamari appetizer was quite good, pizza was n...
# 9976  Peking duck was surprisingly close to authenti...
# 9977  I had the grilled tuna here...and let me tell ...
# 9978  i've had the salmon entree on a few occasions ...
# 9979  3.5 stars\n\ndecent, italian fare. i loved my ...
# 9980  3.5 Stars.\n\nOrdered an Arnold Palmer -- the ...
# 9981  If you're a fan of Wolfgang Puck, you must sav...
# 9982  Went to Postrio for lunch on 3/4/07. I was act...
# 9983  Disclosure:  My cousin is a bartender here\n\n...
# 9984  Stopped in here a while ago for dinner with th...
# 9985  I have to step outside of myself to write this...
# 9986  This is a review of the Postrio CAFE.\n\nWhile...
# 9987  Las Vegas food critic John Curtas (KNPR) picke...
# 9988  I visited Postrio with a friend on Tuesday nig...
# 9989  One of my favorite places to eat dinner in Veg...
# 9990  I will forever dream of that $60 summer truffl...
# 9991  Colleague's friend raved about this place so w...
# 9992  This is based on the cafe experience more so t...
# 9993  I rarely have such mixed feelings about my exp...
# 9994  I think that the setting was more enchanting t...
# 9995  Hubby and I liked this place.\nPizza was plain...
# 9996  I only ate TWICE in Vegas.\n\nNot because I wa...
# 9997  Went to the cafe, which is the patio area.\n\n...
# 9998  This is a review for the cafe.\n\nMy first tri...
# 9999  We came here by chance after watching The Phan...
#
#                   NaiveBayes RFClassification BNBClassification  \
# 0                   negative         negative          negative
# 1                   negative         negative          negative
# 2                   positive         positive          positive
# 3                   negative         negative          negative
# 4                   negative         positive          negative
# 5                   negative         positive          negative
# 6                   positive         negative          positive
# 7                   negative         negative          negative
# 8                   negative         positive          negative
# 9                   positive         positive          positive
# 10    negativewaiter is rude         negative          negative
# 11                  negative         negative          negative
# 12                  negative         negative          negative
# 13                  negative         positive          negative
# 14                  positive         positive          positive
# 15                  positive         positive          positive
# 16                  negative         negative          negative
# 17                  negative         positive          negative
# 18                  positive         positive          positive
# 19                  negative         positive          negative
# 20                  positive         positive          positive
# 21                  negative         positive          negative
# 22                  negative         negative          negative
# 23                  negative         negative          negative
# 24                  negative         negative          negative
# 25                  positive         positive          positive
# 26    negativewaiter is rude         positive          negative
# 27                  negative         positive          negative
# 28                  negative         negative          negative
# 29                  negative         negative          negative
# ...                      ...              ...               ...
# 9970                negative         negative          negative
# 9971                positive         positive          positive
# 9972                negative         negative          negative
# 9973  negativewaiter is rude         positive          negative
# 9974                negative         negative          negative
# 9975                negative         negative          negative
# 9976                positive         positive          positive
# 9977                positive         positive          positive
# 9978                positive         positive          positive
# 9979                positive         positive          positive
# 9980                negative         negative          negative
# 9981                negative         positive          negative
# 9982                positive         negative          negative
# 9983                positive         positive          positive
# 9984                negative         negative          negative
# 9985                negative         negative          negative
# 9986                negative         negative          negative
# 9987                negative         negative          negative
# 9988                positive         positive          positive
# 9989                positive         positive          positive
# 9990                positive         positive          positive
# 9991                negative         negative          negative
# 9992                negative         negative          negative
# 9993  negativewaiter is rude         negative          negative
# 9994                negative         negative          negative
# 9995                negative         positive          negative
# 9996                negative         positive          negative
# 9997                negative         negative          negative
# 9998                negative         positive          negative
# 9999                negative         positive          negative
#
#      LogisticRegressionClassification MNBClassification SGDClassification  \
# 0                            negative          negative          negative
# 1                            negative          negative          negative
# 2                            positive          positive          positive
# 3                            negative          negative          negative
# 4                            positive          negative          negative
# 5                            positive          positive          negative
# 6                            positive          positive          negative
# 7                            positive          positive          positive
# 8                            negative          negative          positive
# 9                            positive          positive          positive
# 10                           negative          negative          negative
# 11                           negative          negative          positive
# 12                           positive          negative          positive
# 13                           negative          negative          negative
# 14                           positive          positive          positive
# 15                           positive          positive          positive
# 16                           negative          negative          negative
# 17                           positive          negative          negative
# 18                           positive          positive          positive
# 19                           negative          negative          negative
# 20                           positive          positive          positive
# 21                           positive          negative          positive
# 22                           negative          positive          negative
# 23                           negative          negative          negative
# 24                           negative          negative          negative
# 25                           positive          positive          positive
# 26                           negative          positive          positive
# 27                           positive          positive          positive
# 28                           negative          negative          negative
# 29                           negative          negative          negative
# ...                               ...               ...               ...
# 9970                         positive          negative          negative
# 9971                         positive          positive          positive
# 9972                         negative          negative          negative
# 9973                         negative          negative          negative
# 9974                         negative          negative          negative
# 9975                         negative          negative          negative
# 9976                         positive          positive          positive
# 9977                         positive          positive          positive
# 9978                         positive          positive          positive
# 9979                         positive          positive          positive
# 9980                         negative          negative          negative
# 9981                         negative          positive          negative
# 9982                         positive          positive          positive
# 9983                         positive          positive          positive
# 9984                         positive          negative          positive
# 9985                         negative          negative          negative
# 9986                         negative          negative          negative
# 9987                         negative          negative          negative
# 9988                         positive          positive          positive
# 9989                         positive          positive          positive
# 9990                         positive          positive          positive
# 9991                         negative          negative          negative
# 9992                         positive          positive          positive
# 9993                         negative          negative          negative
# 9994                         negative          negative          negative
# 9995                         negative          positive          negative
# 9996                         positive          positive          positive
# 9997                         negative          negative          negative
# 9998                         positive          positive          positive
# 9999                         negative          negative          negative
#
#      LinearSVCClassification CombinedClassification
# 0                   negative               negative
# 1                   negative               negative
# 2                   positive               positive
# 3                   negative               negative
# 4                   negative               negative
# 5                   positive               positive
# 6                   negative               positive
# 7                   positive               positive
# 8                   positive               negative
# 9                   positive               positive
# 10                  negative               negative
# 11                  negative               negative
# 12                  positive               positive
# 13                  positive               negative
# 14                  positive               positive
# 15                  positive               positive
# 16                  negative               negative
# 17                  positive               positive
# 18                  positive               positive
# 19                  negative               negative
# 20                  positive               positive
# 21                  positive               positive
# 22                  negative               negative
# 23                  negative               negative
# 24                  negative               negative
# 25                  positive               positive
# 26                  negative               positive
# 27                  positive               positive
# 28                  negative               negative
# 29                  negative               negative
# ...                      ...                    ...
# 9970                positive               negative
# 9971                positive               positive
# 9972                negative               negative
# 9973                negative               negative
# 9974                negative               negative
# 9975                negative               negative
# 9976                negative               positive
# 9977                positive               positive
# 9978                positive               positive
# 9979                positive               positive
# 9980                negative               negative
# 9981                negative               negative
# 9982                negative               positive
# 9983                positive               positive
# 9984                negative               negative
# 9985                negative               negative
# 9986                negative               negative
# 9987                negative               negative
# 9988                positive               positive
# 9989                positive               positive
# 9990                positive               positive
# 9991                negative               negative
# 9992                negative               positive
# 9993                negative               negative
# 9994                negative               negative
# 9995                negative               negative
# 9996                positive               positive
# 9997                negative               negative
# 9998                positive               positive
# 9999                negative               negative
#
# [10000 rows x 10 columns]

# %%
yelpReviewPD.to_pickle("yelpReview10000.p")
